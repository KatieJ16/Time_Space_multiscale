# %% [markdown]
# ## Toy Model 1: 2 spatial modes with different oscillating frequencies

# %% [markdown]
# ### Created by Yuying Liu, 09/23/2019

# %% [markdown]
# $$\Phi(x, t) = u(x)cos(\omega_0 t) + v(x)cos(\omega_1 t + \frac{\pi}{4})$$

# %%
# imports
import os
import sys
import torch
import torch.nn as nn
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from tqdm.notebook import tqdm

module_path = os.path.abspath(os.path.join('../../multiscale_HiTS/src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
import utils
import ResNet as tnet

module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import torch_cae_multilevel_V4 as net
from utils_MrCAE import *

# %% [markdown]
# ## Simulation

# %% [markdown]
# ## MrCAE

# %%
#load data

train_data = np.load('../data/toy1_train_data.npy')
val_data = np.load('../data/toy1_val_data.npy')


# init model & load data
data_path = '../data/toy1.npy'
model_path = '../model/toy1_space/'
result_path = '../result/toy1_space/' 

# trained models at different levels
models_space = {}
print('model names: model_L{level}_{index}')
for file_name in sorted(os.listdir(model_path)):
    model_name, _ = file_name.split('.')
    print(model_name)
    models_space[model_name] = torch.load(os.path.join(model_path, file_name))
# Out:
# model names: model_L{level}_{index}
# model_L0_0
# model_L0_0_16
# model_L0_0_2
# model_L0_0_4
# model_L0_0_8
# model_L0_1
# model_L0_1_2
# model_L0_1_4
# model_L0_1_8
# model_L0_2
# model_L1_0
# model_L1_1
# model_L2_0

# %%
#define some functions
def obtain_data_at_current_level(data, level,n_levels):
#         train_data = self.data[self.train_inds].to(self.device)
#         val_data = self.data[self.val_inds].to(self.device)
#         test_data = self.data[self.test_inds].to(self.device)
        device = 'cuda' if torch.cuda.is_available() else 'cpu'
        for i in range(n_levels - level - 1):
            data = apply_local_op(data.to(device), device, ave=False)

        return data
    
    
def encode(self, x, level, query_in_out_each_level=False, query_hidden=False):
        """
        :param x: a 4D input of NN
        :param level: level index
        :param query_in_out_each_level: if to query the input/output at each level
        (maybe used for enforce losses at different levels)
        :param query_hidden: if to query hidden representations
        :return: output of NN, a list of hidden representations at current level
        """
        # collectors
        all_hidden = dict()
        all_inputs = dict()
        all_outputs = dict()

        # forward prop
        assert level >= 0, print('level index should be a non-negative integer!')
        resolved_maps_dict = self.resolved_maps[str(level)]

        if self.n_filter_groups_each_level['0'] == 1:
            if query_in_out_each_level:
                all_inputs['0'] = x
            encoded = self._modules['L{}_Conv_0'.format(level)](x)

            return encoded
        #else:
        i = self.n_filter_groups_each_level['0']-1
#         print('L{}_Conv_{}'.format(level, i))
        encoded = self._modules['L{}_Conv_{}'.format(level, i)](x)
#         if self.use_maps:
        masked_encoded = apply_mask(encoded, resolved_maps_dict[str(i - 1)])
#         else:
#             masked_encoded = encoded
        return masked_encoded
    
def decode(self, encoded, level, y=None, query_in_out_each_level=False, query_hidden=False):
        """
        :param x: a 4D input of NN
        :param level: level index
        :param query_in_out_each_level: if to query the input/output at each level
        (maybe used for enforce losses at different levels)
        :param query_hidden: if to query hidden representations
        :return: output of NN, a list of hidden representations at current level
        """
        # collectors
        all_hidden = dict()
        all_inputs = dict()
        all_outputs = dict()

        # forward prop
        assert level >= 0, print('level index should be a non-negative integer!')
#         resolved_maps_dict = self.resolved_maps[str(level)]

        if self.n_filter_groups_each_level['0'] == 1:
            if query_hidden:
                all_hidden['L0_0'] = encoded
            # ----- pad -----
            encoded = torch.nn.functional.pad(encoded, (1, 1, 1, 1), 'replicate')
            # ---------------
            y = self._modules['L{}_deConv_0'.format(level)](encoded)
            # chop off the boundaries
            y = y[:, :, 2:-2, 2:-2]
            
            
        else:
            i =self.n_filter_groups_each_level['0'] -1
            y = self._modules['L{}_deConv_{}'.format(level, i)](encoded)
            
        return y

# %%
# #encode the data 
model = models_space['model_L0_0']
n_train, n_timesteps, _,_ = train_data.shape
train_encoded_0_0 = torch.zeros((n_train, n_timesteps, 15,15))
val_encoded_0_0 = torch.zeros((len(val_data), n_timesteps, 15,15))
data = torch.tensor(train_data).unsqueeze(2).float()

val_data_layer0 = torch.zeros((len(val_data), n_timesteps, 31,31))
train_data_layer0 = torch.zeros((len(train_data), n_timesteps, 31,31))
for i in tqdm(range(len(train_data))):
    data_this = obtain_data_at_current_level(data[i], 0,3)
    train_data_layer0[i] = data_this[:,0]
    encoded = encode(model, data_this, 0)
    train_encoded_0_0[i] = encoded[:,0]

data = torch.tensor(val_data).unsqueeze(2).float()
for i in tqdm(range(len(val_data))):
    data_this = obtain_data_at_current_level(data[i], 0,3)
#     print(data_this.shape)
    val_data_layer0[i] = data_this[:,0]
    encoded = encode(model, data_this, 0)
    val_encoded_0_0[i] = encoded[:,0]
    
    
# load models
step_sizes = [8]
models_time = list()
for step_size in step_sizes:
    print('model_L0_0_{}.pt'.format(step_size))
    models_time.append(torch.load(os.path.join(model_path,'model_L0_0_{}.pt'.format(step_size)),map_location='cpu'))
#     models.append(torch.load(os.path.join(model_path, 'model_D{}_noise0.0.pt'.format(step_size)), map_location='cpu'))

# fix model consistencies trained on gpus (optional)
for model in models_time:
    model.device = 'cpu'
    model._modules['increment']._modules['activation'] = torch.nn.ReLU()
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# model_L0_0_8.pt

# %%
model = models_time[0]
#get encoded versions of validation adn training
n_steps = 499
test_data_0_0 = torch.tensor(val_encoded_0_0).flatten(start_dim=2).float()
y_preds = model.uni_scale_forecast(torch.tensor(test_data_0_0[:, 0, :]).float(), n_steps=n_steps)
encoded_t1_val = torch.reshape(y_preds, (100,499,15,15))

y_preds = model.uni_scale_forecast(torch.tensor(train_encoded_0_0[:,0,:]).flatten(start_dim=1).float(), n_steps=n_steps)
encoded_t1_train = torch.reshape(y_preds, (len(y_preds),n_steps,15,15))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# /home/kjohnst/multiscale_HiTS/src/ResNet.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds.insert(0, torch.tensor(x_init).float().to(self.device))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
# model = models['model_L0_0']
# print(encoded_t1.shape)
# decoded = decode(model, encoded_t1,0)

device='cuda'

# #decode the data 
model = models_space['model_L0_0']
print(encoded_t1_train.shape)
n_train, n_timesteps, _,_ = train_data.shape
train_decoded_0_0 = torch.zeros((n_train, n_timesteps-1, 31,31))
val_decoded_0_0 = torch.zeros((len(val_data), n_timesteps-1, 31,31))
data = encoded_t1_train.unsqueeze(2).float().to(device)
for i in tqdm(range(len(train_data))):
    decoded = decode(model, data[i], 0)
    train_decoded_0_0[i] = decoded[:,0]

# data = torch.tensor(val_data).unsqueeze(2).float()
data = encoded_t1_val.unsqueeze(2).float().to(device)
for i in tqdm(range(len(val_data))):
    decoded = decode(model, data[i], 0)
    val_decoded_0_0[i] = decoded[:,0]
# Out:
# torch.Size([500, 499, 15, 15])
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
class MultiScaleDynamicsDataSet():
    def __init__(self, train_data, val_data, train_data_output=None, val_data_output=None, n_levels=0, map_path=None, train_ratio=0.7, valid_ratio=0.2):
        # load data
#         data = np.load(data_path)
#         self.data = torch.tensor(data).unsqueeze(1).float()
#         #
#         if map_path is not None:
#             map_data = 1 - np.load(map_path)
#             self.map_data = torch.tensor(map_data).float()
#         else:
        

        self.nt, self.nx, self.ny = train_data.shape
        # partition
        indices = np.arange(self.nt)
        np.random.shuffle(indices)
        n_train = int(train_ratio*self.nt)
        n_val = int(valid_ratio*self.nt)
        self.n_train = n_train
        self.n_val = n_val
        self.n_test = self.nt - n_train - n_val
        self.train_inds = indices[:n_train]
        self.val_inds = indices[n_train:n_train+n_val]
        self.test_inds = indices[n_train+n_val:]
        #
        self.n_levels = n_levels
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
#         self.map_data = self.map_data.to(self.device)
        
        self.data = torch.tensor(train_data).unsqueeze(1).float().to('cuda') 
        self.map_data = torch.ones(self.data.shape[-2:]).float().to('cuda')
        self.train_data = torch.tensor(train_data).unsqueeze(1).float() 
        self.val_data = torch.tensor(val_data).unsqueeze(1).float() 
        
        if train_data_output is None:
            self.train_data_output = self.train_data
            self.val_data_output = self.val_data
        else:
            self.train_data_output = torch.tensor(train_data_output).unsqueeze(1).float() 
            self.val_data_output = torch.tensor(val_data_output).unsqueeze(1).float() 
        

    def obtain_data_at_current_level(self, level):
        train_data = self.train_data#self.data[self.train_inds].to(self.device)
        val_data = self.val_data#self.data[self.val_inds].to(self.device)
        test_data = self.val_data#self.data[self.test_inds].to(self.device)

        for _ in range(self.n_levels - level - 1):
            train_data = apply_local_op(train_data, self.device, ave=False)
            val_data = apply_local_op(val_data, self.device, ave=False)
            test_data = apply_local_op(test_data, self.device, ave=False)

        return train_data, val_data, test_data
    
    def obtain_data_at_current_level_output(self, level):
        train_data = self.train_data_output#self.data[self.train_inds].to(self.device)
        val_data = self.val_data_output#self.data[self.val_inds].to(self.device)
        test_data = self.val_data_output#self.data[self.test_inds].to(self.device)

        for _ in range(self.n_levels - level - 1):
            train_data = apply_local_op(train_data, self.device, ave=False)
            val_data = apply_local_op(val_data, self.device, ave=False)
            test_data = apply_local_op(test_data, self.device, ave=False)

        return train_data, val_data, test_data

# %%
def train_arch(self, dataset, max_epoch, batch_size,
                   tol=None, lr=1e-3, w=0.5, verbose=1, cur_level=None):
        """
        :param dataset: a MultiScaleDynamicsDataSet object
        :param max_epoch: maximum number of epochs
        :param batch_size: batch size
        :param tol: error tolerance (default is None)
        :param lr: learning rate
        :param w: w: loss = w * l2_loss + (1-w) * l_inf_loss
        :param verbose: verbose level
        :return: a list of train_losses, val_losses and timings
        """
        # prepare data at this level
        train_data, val_data, _ = dataset.obtain_data_at_current_level(cur_level)
        output_train, output_val, _ = dataset.obtain_data_at_current_level_output(cur_level)
        
        # specify optimizer
        optimizer = torch.optim.Adam(self.parameters(), lr=lr, eps=1e-3, weight_decay=1e-5)
        criterion = torch.nn.MSELoss(reduction='none')

        # collectors
        val_losses = list()
        train_losses = list()
        max_pos_set = set()

        # training
        epoch = 0
        ave_loss_old = 1e+10
        best_local_val_err = 1e+10
        best_state_dict = self.state_dict()
        while epoch < max_epoch:
            epoch += 1
            # =================== forward =====================
#             new_idxs = torch.randperm(dataset.n_train)
#             batch_idxs = new_idxs[:batch_size]
#             batch_train_data = train_data[batch_idxs, :, :, :]
            output, _, _, _ = self.forward(train_data, cur_level)
            output_val, _, _, _ = self.forward(val_data, cur_level)
            # =============== calculate losses ================
            mean_loss_train = criterion(output, output_train).mean()
            max_loss_train = criterion(output, output_train).mean(0).max()
            assert 0 <= w <= 1, print('w should between 0 and 1 (inclusive)!')
            loss = w * mean_loss_train + (1 - w) * max_loss_train
            mean_loss_val = criterion(output_val, val_data).mean()
            max_loss_val = criterion(output_val, val_data).mean(0).max()
            loss_val = w * mean_loss_val + (1 - w) * max_loss_val
            if loss_val.item() < best_local_val_err:
                best_local_val_err = loss_val.item()
                best_state_dict = self.state_dict()
            # compute global scale losses
#             global_mean_loss, global_max_loss, _ = self.compute_global_loss(dataset, output, cur_level, range(len(train_data)))#dataset.train_inds[batch_idxs])
#             global_mean_val_loss, global_max_val_loss, tup = self.compute_global_loss(dataset, output_val, cur_level, dataset.val_inds)
#             global_loss = w * global_mean_loss + (1-w) * global_max_loss
#             global_val_loss = w * global_mean_val_loss + (1-w) * global_max_val_loss
            # =================== backward ====================
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # ================= collect stat ==================
            train_losses.append(mean_loss_train.item())#global_loss.item())
            val_losses.append(mean_loss_val.item())#global_val_loss.item())
#             max_pos_set.add(tup)
            # =================== log =========================
            # 1st epoch
#             if epoch == 1 and verbose:
#                 # init err
#                 print('losses printing format: local: mse/max/overall, global: mse/max/overall')
#                 print('epoch [1/{}]'.format(max_epoch))
#                 print('[training set] local: {:.4f}/{:.4f}/{:.4f}, global: {:.4f}/{:.4f}/{:.4f}'.format(mean_loss_train.item(), max_loss_train.item(), loss.item(), global_mean_loss.item(), global_max_loss.item(), global_loss.item()))
#                 print('[validation set] local: {:.4f}/{:.4f}/{:.4f}, global: {:.4f}/{:.4f}/{:.4f}'.format(mean_loss_val.item(), max_loss_val.item(), loss_val.item(), global_mean_val_loss.item(), global_max_val_loss.item(), global_val_loss.item()))
            # every 1/10 max_epoch
            if epoch % (max_epoch // 10) == 0:
                print('epoch [{}/{}]:'.format(epoch, max_epoch))
                print('[training set] local: {:.4f}/{:.4f}/{:.4f}'.format(mean_loss_train.item(), max_loss_train.item(), loss.item()))#, global_mean_loss.item(), global_max_loss.item(), global_loss.item()))
                print('[validation set] local: {:.4f}/{:.4f}/{:.4f}'.format(mean_loss_val.item(), max_loss_val.item(), loss_val.item()))#, global_mean_val_loss.item(), global_max_val_loss.item(), global_val_loss.item()))
                # check for early stopping
                if tol is not None:
                    # check if fully resolved?
                    train_output, _, _, _ = self.forward(train_data, cur_level)
                    fully_resolved, _, _ = check_pixel_level_loss(train_data, train_output, tol=tol, device=self.device, w=0.5)
                    if fully_resolved and epoch < max_epoch:
                        print('early stopping at {}th iteration due to satisfying reconstruction!'.format(epoch))
                        break
                if epoch > max_epoch // 2 and epoch < max_epoch:
                    ave_loss = np.mean(train_losses[-(max_epoch // 10):])
                    if (ave_loss_old - ave_loss) / ave_loss_old < 1e-3:
                        # improvement is so small that we consider it as convergence
                        print('early stopping at {}th iteration due to slow convergence!'.format(epoch))
                        break
                    ave_loss_old = ave_loss

        # calculate the best validation error
        self.load_state_dict(best_state_dict)
        output_val, _, _, _ = self.forward(val_data, cur_level)
#         global_mean_val_loss, global_max_val_loss, _ = self.compute_global_loss(dataset, output_val, cur_level, dataset.val_inds)
#         global_val_loss = w * global_mean_val_loss + (1-w) * global_max_val_loss
        best_val_loss = mean_loss_val.item()#global_val_loss.item()
        # check this level is clear if tolerance threshold is enabled
        filter_index = self.n_filter_groups_each_level[str(cur_level)] - 1
        train_output, _, _, _ = self.forward(train_data, cur_level)
        if tol is not None:
            _, _, resolved_map = check_pixel_level_loss(train_data, train_output, tol=tol, device=self.device, w=0.5)
            self.resolved_maps[str(cur_level)][str(filter_index)] = resolved_map.float()
            if resolved_map.all():
                self.level_clear[str(cur_level)] = True

        return self, val_losses, best_val_loss,# max_pos_set

# %%
#the important parts of train_net_one_stage
activation=torch.nn.ReLU()
n_levels = 1
use_maps = True
# model_this_space = net.CAE(n_levels=n_levels, activation=activation, use_maps=use_maps)

std=0.02

#load previous model 
file_name = "model_L0_0.pt"
print(os.path.join(model_path, file_name))
model = torch.load(os.path.join(model_path, file_name))

n_filters = 1
std = 0.02
model.deeper_op(std=std)

#make the filter be for the t+1 time
# d1 = train_data_layer0[:,1:]

# d2 = train_decoded_0_0
# loss = torch.mean((d1 - d2)**2, dim=(0,1), keepdim=True).to('cuda')
# # print(loss)
# loss_summary = apply_local_op(loss, device).squeeze()
# resolved_map = loss_summary <= 0.001
# model.resolved_maps[str(0)][str(0)] = resolved_map.float()


# model.wider_op(n_filters=n_filters, std=std)

# print(encode(model,train_decoded_0_0[0].unsqueeze(1).to(device), 0).shape)

print("train_data = ", train_data.shape)
# train_data = np.load('../data/toy1_train_data.npy')
# val_data = np.load('../data/toy1_val_data.npy')
print("train_data = ", train_data.shape)
dataset = MultiScaleDynamicsDataSet(torch.tensor(train_data[:,0]).to('cuda'), torch.tensor(val_data[:,0]).to('cuda'), n_levels=3)
print("val_decoded_0_0[0,:].shape = ", val_decoded_0_0[0,:].shape)
print("val_data_layer0[0,1:] shape = ", val_data_layer0[0,1:].shape)

# plt.imshow(train_data_layer0[0,0].cpu().detach().numpy())
# plt.colorbar()
# plt.show()
# plt.imshow(train_decoded_0_0[0,0].cpu().detach().numpy())
# plt.colorbar()
# plt.show()
# print("train_decoded_0_0 shape = ", train_decoded_0_0[:,0].shape)
# print("train_data_layer0 shape = ", train_data_layer0[:,0].shape)

# train_data, val_data,_ = dataset.obtain_data_at_current_level(1)
# print(train_data.shape)

model_this_space, val_losses, best_val_loss= train_arch(model, dataset, max_epoch=3000, batch_size=500, cur_level=1)
# Out:
# ../model/toy1_space/model_L0_0.pt
# train_data =  (500, 500, 127, 127)
# train_data =  (500, 500, 127, 127)
# val_decoded_0_0[0,:].shape =  torch.Size([499, 31, 31])
# val_data_layer0[0,1:] shape =  torch.Size([499, 31, 31])
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# epoch [300/3000]:
# [training set] local: 0.0000/0.0029/0.0015
# [validation set] local: 0.0000/0.0031/0.0016
# epoch [600/3000]:
# [training set] local: 0.0000/0.0028/0.0014
# [validation set] local: 0.0001/0.0030/0.0015
# epoch [900/3000]:
# [training set] local: 0.0001/0.0027/0.0014
# [validation set] local: 0.0001/0.0029/0.0015
# epoch [1200/3000]:
# [training set] local: 0.0001/0.0026/0.0013
# [validation set] local: 0.0001/0.0029/0.0015
# epoch [1500/3000]:
# [training set] local: 0.0001/0.0025/0.0013
# [validation set] local: 0.0001/0.0027/0.0014
# epoch [1800/3000]:
# [training set] local: 0.0000/0.0024/0.0012
# [validation set] local: 0.0001/0.0026/0.0013
# epoch [2100/3000]:
# [training set] local: 0.0000/0.0023/0.0012
# [validation set] local: 0.0000/0.0025/0.0013
# epoch [2400/3000]:
# [training set] local: 0.0000/0.0022/0.0011
# [validation set] local: 0.0000/0.0024/0.0012
# epoch [2700/3000]:
# [training set] local: 0.0000/0.0021/0.0011
# [validation set] local: 0.0000/0.0023/0.0012
# epoch [3000/3000]:
# [training set] local: 0.0000/0.0019/0.0010
# [validation set] local: 0.0000/0.0021/0.0011

# %%
torch.save(model_this_space, os.path.join(model_path, "model_L1_0.pt"))

# %%
model_this_space = torch.load(os.path.join(model_path, "model_L1_0.pt"))

# %%
print(d1.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6883416f3ba3> in <module>()
# ----> 1 print(d1.shape)
#
# NameError: name 'd1' is not defined

# %%
# train_data = np.load('../data/toy1_train_data.npy')
# val_data = np.load('../data/toy1_val_data.npy')
train_data_this = obtain_data_at_current_level(torch.tensor(train_data[0]).unsqueeze(1).float(), 1,3)

# train_data, val_data,_ = dataset.obtain_data_at_current_level(0)

model_this_space = torch.load(os.path.join(model_path, "model_L1_0.pt"))

encoded = encode(model_this_space, train_data_this, 0)
plt.imshow(encoded[0,0].cpu().detach().numpy())
plt.title("encoded for L1_0")
plt.colorbar()
plt.show()


decoded = decode(model_this_space, encoded, 0)
plt.imshow(decoded[0,0].cpu().detach().numpy())
plt.title("decoded for L1_0")
plt.colorbar()
plt.show()

vmin=0.25
vmax=0.65

forwarded,_,_,_ = model_this_space( train_data_this, 0)
plt.imshow(forwarded[0,0].cpu().detach().numpy(),vmin=vmin,vmax=vmax)
plt.title("forward for L1_0")
plt.colorbar()
plt.show()

# forwarded,_,_,_ = model_this_space( train_data_this, 0)
plt.imshow(train_data_this[0,0].cpu().detach().numpy(),vmin=vmin,vmax=vmax)
plt.colorbar()
plt.show()

# %%
print(encoded.shape)
# Out:
# torch.Size([500, 1, 15, 15])

# %%
# plt.plot(train_data_this[:,0,18,12].cpu().detach().numpy())
# plt.plot(forwarded[:,0,18,12].cpu().detach().numpy())

plt.plot(train_data_this[:,0,0,0].cpu().detach().numpy())
plt.plot(forwarded[:,0,0,0].cpu().detach().numpy())

# plt.plot(forwarded[:,0,0,0].cpu().detach().numpy())

# %%
# #encode the data 
train_data = np.load('../data/toy1_train_data.npy')
val_data = np.load('../data/toy1_val_data.npy')
model = model_this_space#models_space['model_L0_1']
n_train, n_timesteps, _,_ = train_decoded_0_0.shape
train_encoded_0_1 = torch.zeros((n_train, n_timesteps, 15,15))
val_encoded_0_1 = torch.zeros((len(val_decoded_0_0), n_timesteps, 15,15))
data = torch.tensor(train_decoded_0_0).unsqueeze(2).float().to('cuda')
print(data.shape)

val_data_layer1 = torch.zeros((len(val_data), n_timesteps, 31,31))
train_data_layer1 = torch.zeros((len(train_data), n_timesteps, 31,31))
for i in tqdm(range(len(train_data))):
    data_this = data[i]#obtain_data_at_current_level(data[i], 0,3)
    train_data_layer1[i] = data_this[:,0]
    encoded = encode(model, data_this, 0)
    train_encoded_0_1[i] = encoded[:,0]

data = torch.tensor(val_decoded_0_0).unsqueeze(2).float().to('cuda')
for i in tqdm(range(len(val_data))):
    data_this = data[i]#obtain_data_at_current_level(data[i], 0,3)
#     print(data_this.shape)
    val_data_layer1[i] = data_this[:,0]
    encoded = encode(model, data_this, 0)
    val_encoded_0_1[i] = encoded[:,0]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# torch.Size([500, 499, 1, 31, 31])
#   0%|          | 0/500 [00:00<?, ?it/s]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# plt.plot(val_encoded_0_1[:,0,0,0].cpu().detach().numpy())
plt.imshow(encoded[0,0].cpu().detach().numpy())
plt.title("encoded for L0_1")
plt.colorbar()
plt.show()

decoded = decode(model, encoded, 0)
plt.imshow(decoded[0,0].cpu().detach().numpy())
plt.title("decoded for L0_1")
plt.colorbar()
plt.show()

vmin = 0.17
vmax = 0.46

# sum_decoded = decoded[0,0] + data_this[0,0]
plt.imshow(data_this[0,0].cpu().detach().numpy(),vmin=vmin,vmax=vmax)
plt.title("decoded for L0_0")
plt.colorbar()

plt.show()

sum_decoded = decoded[0,0] + data_this[0,0]
plt.imshow(sum_decoded.cpu().detach().numpy(),vmin=vmin,vmax=vmax)
plt.title("sum_decoded for L0_1")
plt.colorbar()

plt.show()

plt.imshow(val_data_layer0[-1,1].cpu().detach().numpy(),vmin=vmin,vmax=vmax)
plt.title("truth")
plt.colorbar()

# %%
#doing the time training
print("inside train_one_timestep")
i=None
j=None
step_size = 4
dt=1
n_forward = 10
arch = [225, 225*2, 225*2, 225*2, 225]
batch_size = 500
lr = 0.001

model_name = 'model_L0_1_{}.pt'.format(step_size)#{}_D{}_noise{}.pt'.format(current_size, step_size, noise)
model_path_this = os.path.join(model_path, model_name)

dataset = utils.DataSet(train_encoded_0_1.flatten(start_dim=2), val_encoded_0_1.flatten(start_dim=2), val_encoded_0_1.flatten(start_dim=2), dt, step_size, n_forward)
print('create model {} ...'.format(model_name))
model = tnet.ResNet(arch=arch, dt=dt, step_size=step_size)

# # training
model.train_net(dataset, max_epoch=30000, batch_size=batch_size, lr=lr,
            model_path=os.path.join(model_path, model_name))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# inside train_one_timestep
# create model model_L0_1_4.pt ...
# /home/kjohnst/multiscale_HiTS/src/utils.py:38: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.train_x = torch.tensor(train_data[:, x_idx, :]).float().to(self.device)
# /home/kjohnst/multiscale_HiTS/src/utils.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.train_ys = torch.tensor(train_data[:, y_start_idx:y_end_idx:step_size, :]).float().to(self.device)
# /home/kjohnst/multiscale_HiTS/src/utils.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.val_x = torch.tensor(val_data[:, x_idx, :]).float().to(self.device)
# /home/kjohnst/multiscale_HiTS/src/utils.py:41: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.val_ys = torch.tensor(val_data[:, y_start_idx:y_end_idx:step_size, :]).float().to(self.device)
# /home/kjohnst/multiscale_HiTS/src/utils.py:42: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.test_x = torch.tensor(test_data[:, 0, :]).float().to(self.device)
# /home/kjohnst/multiscale_HiTS/src/utils.py:43: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.test_ys = torch.tensor(test_data[:, 1:, :]).float().to(self.device)
# epoch 1000, training loss 1.20848681035568e-05, validation loss 1.2280054761504289e-05
# (--> new model saved @ epoch 1000)
# epoch 2000, training loss 6.144471171865007e-06, validation loss 6.283102266024798e-06
# (--> new model saved @ epoch 2000)
# epoch 3000, training loss 8.397917554248124e-06, validation loss 8.800929208518937e-06
# epoch 4000, training loss 4.027415798191214e-06, validation loss 4.333337983553065e-06
# (--> new model saved @ epoch 4000)
# epoch 5000, training loss 9.227898772223853e-06, validation loss 9.166063136945013e-06
# epoch 6000, training loss 7.93749131844379e-06, validation loss 7.902686775196344e-06
# epoch 7000, training loss 7.76685010350775e-06, validation loss 7.878497854107991e-06
# epoch 8000, training loss 1.3513173144019675e-05, validation loss 1.4313882275018841e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-ba50b610d6f9> in <module>()
#      19 # # training
#      20 model.train_net(dataset, max_epoch=30000, batch_size=batch_size, lr=lr,
# ---> 21             model_path=os.path.join(model_path, model_name))
#      22
#      23 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#
# ~/multiscale_HiTS/src/ResNet.py in train_net(self, dataset, max_epoch, batch_size, w, lr, model_path)
#     135             # =============== calculate losses ================
#     136             train_loss = self.calculate_loss(batch_x, batch_ys, w=w)
# --> 137             val_loss = self.calculate_loss(dataset.val_x, dataset.val_ys, w=w)
#     138             # ================ early stopping =================
#     139             if best_loss <= 1e-8:
#
# ~/multiscale_HiTS/src/ResNet.py in calculate_loss(self, x, ys, w)
#     172         y_prev = x
#     173         for t in range(n_steps):
# --> 174             y_next = self.forward(y_prev)
#     175             y_preds[:, t, :] = y_next
#     176             y_prev = y_next
#
# ~/multiscale_HiTS/src/ResNet.py in forward(self, x_init)
#      76         :return: next step prediction of shape batch_size x input_dim
#      77         """
# ---> 78         return x_init + self._modules['increment'](x_init)
#      79
#      80     def uni_scale_forecast(self, x_init, n_steps):
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/multiscale_HiTS/src/ResNet.py in forward(self, x)
#      28         """
#      29         for i in range(self.n_layers - 1):
# ---> 30             x = self.activation(self._modules['Linear_{}'.format(i)](x))
#      31         # no nonlinear activations in the last layer
#      32         x = self._modules['Linear_{}'.format(self.n_layers - 1)](x)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# ~/.local/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# KeyboardInterrupt:

# %%
# load models
step_sizes = [4]
models_time = list()
for step_size in step_sizes:
    print('model_L0_1_{}.pt'.format(step_size))
    models_time.append(torch.load(os.path.join(model_path,'model_L0_1_{}.pt'.format(step_size)),map_location='cpu'))
#     models.append(torch.load(os.path.join(model_path, 'model_D{}_noise0.0.pt'.format(step_size)), map_location='cpu'))

# fix model consistencies trained on gpus (optional)
for model in models_time:
    model.device = 'cpu'
    model._modules['increment']._modules['activation'] = torch.nn.ReLU()
# Out:
# model_L0_1_4.pt

# %%
# uniscale time-stepping with NN
preds_mse = list()
times = list()

# test_data = val_data
ks = [1]
n_steps = val_encoded_0_1.shape[1] - 1
t = [dt*(step+1) for step in range(n_steps)]
criterion = torch.nn.MSELoss(reduction='none')

test_data = torch.tensor(val_encoded_0_1).flatten(start_dim=2).float()
print(test_data.shape)

n_steps = 498
for model in tqdm(models_time):
    y_preds = model.uni_scale_forecast(torch.tensor(val_encoded_0_1[:, 0, :]).flatten(start_dim=1).float(), n_steps=n_steps)
#     end = time.time()
#     times.append(end - start)
    preds_mse.append(criterion(torch.tensor(val_encoded_0_1[:, 1:, :]).flatten(start_dim=2).float(), y_preds).mean(-1))
    for i in [0,140]:#range(1):
        
        plt.plot(test_data[1, 1:, i].detach().numpy(),label="Truth")
        plt.plot(y_preds[1,:,i], label="predicted")
        x = y_preds[1,::model.step_size,i]
        plt.title("step_size = 4, i = "+str(i))
        plt.legend()
        plt.show()
#         plt.plot(np.arange(len(x))*model.step_size,x, '.k')
#     plt.xlim([0,200])
    plt.legend()
    plt.title("step size = "+ str(model.step_size))
    plt.show()
    
# visualize forecasting error at each time step    
fig = plt.figure(figsize=(20, 8))
colors=iter(plt.cm.rainbow(np.linspace(0, 1, len(step_sizes))))
for k in range(len(preds_mse)):
    err = preds_mse[k]
    mean = err.mean(0).detach().numpy()
    rgb = next(colors)
    plt.plot(t, np.log10(mean), linestyle='-', color=rgb, linewidth=3.0, label='$\Delta\ t$={}'.format(step_sizes[k]*dt))
plt.legend(fontsize=20, loc='upper right')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# torch.Size([100, 499, 225])
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # This is added back by InteractiveShellApp.init_path()
#   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   app.launch_new_instance()
# /home/kjohnst/multiscale_HiTS/src/ResNet.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds.insert(0, torch.tensor(x_init).float().to(self.device))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# No handles with labels found to put in legend.
# (array([-6. , -5.5, -5. , -4.5, -4. , -3.5, -3. , -2.5]),
#  <a list of 8 Text yticklabel objects>)

# %%
# model = models_time[0]
#get encoded versions of validation adn training
# print(torch.tensor(test_data[:, 0, :]).float().shape)
y_preds = model.uni_scale_forecast(torch.tensor(test_data[:, 0, :]).float(), n_steps=n_steps)
# print(test_data.shape)
# print(y_preds.shape)
encoded_t1_val = torch.reshape(y_preds, (len(y_preds),n_steps,15,15))
# print(encoded_t1.shape)
# print(val_encoded.shape)

# print(torch.tensor(train_encoded[:,0,:]).flatten(start_dim=2).float().shape)
y_preds = model.uni_scale_forecast(torch.tensor(train_encoded_0_1[:,0,:]).flatten(start_dim=1).float(), n_steps=n_steps)
# print(y_preds.shape)
encoded_t1_train = torch.reshape(y_preds, (len(y_preds),n_steps,15,15))
# print(encoded_t1_train.shape)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   after removing the cwd from sys.path.
# /home/kjohnst/multiscale_HiTS/src/ResNet.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds.insert(0, torch.tensor(x_init).float().to(self.device))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   if sys.path[0] == '':

# %%
plt.imshow(encoded_t1_val[0,4])#, vmin=-0.01, vmax=0.02)
plt.colorbar()
plt.title("encoded time t+1 predicted")
plt.show()

plt.imshow(val_encoded_0_1[0,5].cpu().detach().numpy())#, vmin=-0.01, vmax=0.02)
plt.title("encoded time t+1 truth")
plt.colorbar()
plt.show()

print(val_encoded_0_1.shape)
print(encoded_t1_val.shape)
mse = np.mean(((torch.reshape(val_encoded_0_1, (100,499,15,15))[:,1:] - encoded_t1_val)**2).cpu().detach().numpy(), axis=(0,2,3))
plt.xlabel("time")
plt.semilogy(mse)
plt.show()

mse = np.mean(((torch.reshape(val_encoded_0_1, (100,499,15,15))[:,1:] - encoded_t1_val)**2).cpu().detach().numpy(), axis=(0,1))
plt.imshow(mse)
plt.colorbar()
plt.show()
# Out:
# torch.Size([100, 499, 15, 15])
# torch.Size([100, 498, 15, 15])

# %%
# model = models['model_L0_0']
# print(encoded_t1.shape)
# decoded = decode(model, encoded_t1,0)

# #decode the data 
model = model_this_space#models_space['model_L0_0']
print(encoded_t1_train.shape)
n_train, n_timesteps, _,_ = train_data.shape
train_decoded_0_1 = torch.zeros((n_train, n_steps, 31,31))
val_decoded_0_1 = torch.zeros((len(val_data), n_steps, 31,31))
data = encoded_t1_train.unsqueeze(2).float().to(device)
for i in tqdm(range(len(train_data))):
#     print(data[i].shape)
#     data_this = obtain_data_at_current_level(data[i], 0,3)
    decoded = decode(model, data[i], 0)
#     print(train_encoded.shape)
#     print(encoded.shape)
    train_decoded_0_1[i] = decoded[:,0]

# data = torch.tensor(val_data).unsqueeze(2).float()
data = encoded_t1_val.unsqueeze(2).float().to(device)
for i in tqdm(range(len(val_data))):
#     print(data[i].shape)
#     data_this = obtain_data_at_current_level(data[i], 0,3)
    decoded = decode(model, data[i], 0)
    val_decoded_0_1[i] = decoded[:,0]
# Out:
# torch.Size([500, 498, 15, 15])
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
vmin = 0.5#torch.min(val_decoded[0,0])
vmax = 0.8#torch.max(val_decoded[0,0])

plt.imshow(val_decoded[0,82].cpu().detach().numpy())#, vmin=vmin, vmax=vmax)
plt.title("Decoded t+85 predicted")
plt.colorbar()
plt.show()

sum_total_decode = val_decoded + val_decoded_0_0[:,1:]
plt.imshow(sum_total_decode[0,84].cpu().detach().numpy(), vmin=vmin, vmax=vmax)
plt.title("sum_total_decode t+85 predicted")
plt.colorbar()
plt.show()

data = torch.tensor(train_data[0]).unsqueeze(1).float()
print(data.shape)
data_this = obtain_data_at_current_level(data, 0,3)
plt.imshow(val_data_layer0[0,84].cpu().detach().numpy(),vmin=vmin, vmax=vmax)
plt.colorbar()
plt.title("t+85 truth")
plt.show()

# print(train_decoded[0].shape)
# print(data_this[1:,0].shape)

print(val_data_layer0.shape)
print(val_decoded.shape)
mse = np.mean(((sum_total_decode.cpu() - val_data_layer0[:,2:].cpu())**2).cpu().detach().numpy(), axis=(0,2,3))
plt.xlabel("time")
plt.semilogy(mse)
plt.title("mse for decoded data L0_1")
plt.show()
# Out:
# torch.Size([500, 1, 127, 127])
# torch.Size([100, 500, 31, 31])
# torch.Size([100, 498, 31, 31])

# %%
np.argmax(mse)
# Out:
# 82

# %%
plt.plot(sum_total_decode[0,:,5,5].cpu().detach().numpy())
plt.plot(val_data_layer0[0,1:,5,5].cpu().detach().numpy())


# plt.plot(val_data_layer0[0,1:,18,12].cpu().detach().numpy())
# plt.plot(sum_total_decode[0,:,18,12].cpu().detach().numpy())

# %%
sum_total_decode_train = train_decoded + train_decoded_0_0

d1 = train_data_layer0[:,1:100]
d2 = sum_total_decode_train[:,:99]
print(d1.shape)
print(d2.shape)
loss = torch.mean((d1 - d2)**2, dim=(0,1), keepdim=True).to('cuda')
# print(loss)
loss_summary = apply_local_op(loss, device).squeeze()
resolved_map = loss_summary <= 0.001
# print(loss_summary)
plt.imshow(np.log(loss_summary.cpu().detach().numpy()))
plt.colorbar()
plt.show()
# plt.imshow(loss_summary.cpu().detach().numpy())
# plt.colorbar()
# print((loss_summary <= 0.001))

plt.imshow(resolved_map.cpu().detach().numpy())

# model_new = make_smaller(model, train_data_layer0[:,1:].to('cuda'), train_decoded_0_0.to('cuda'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-f70a1a748bad> in <module>()
# ----> 1 sum_total_decode_train = train_decoded + train_decoded_0_0
#       2
#       3 d1 = train_data_layer0[:,1:100]
#       4 d2 = sum_total_decode_train[:,:99]
#       5 print(d1.shape)
#
# RuntimeError: The size of tensor a (498) must match the size of tensor b (499) at non-singleton dimension 1

# %%
#need to do next training 

d1 = train_data_layer0[:,1:]
d2 = train_decoded_0_0
print(d1.shape)
print(d2.shape)
loss = torch.mean((d1 - d2)**2, dim=(0,1), keepdim=True).to('cuda')
# print(loss)
loss_summary = apply_local_op(loss, device).squeeze()
resolved_map = loss_summary <= 0.001
print(loss_summary)
# plt.imshow(loss_summary.cpu().detach().numpy())
# plt.colorbar()
print((loss_summary <= 0.001))

plt.imshow(resolved_map.cpu().detach().numpy())

# model_new = make_smaller(model, train_data_layer0[:,1:].to('cuda'), train_decoded_0_0.to('cuda'))
# Out:
# torch.Size([500, 499, 31, 31])
# torch.Size([500, 499, 31, 31])
# tensor([[0.0011, 0.0008, 0.0006, 0.0007, 0.0005, 0.0006, 0.0011, 0.0009, 0.0007,
#          0.0007, 0.0007, 0.0005, 0.0007, 0.0007, 0.0005],
#         [0.0007, 0.0007, 0.0007, 0.0008, 0.0007, 0.0006, 0.0010, 0.0009, 0.0007,
#          0.0007, 0.0006, 0.0005, 0.0009, 0.0007, 0.0006],
#         [0.0007, 0.0008, 0.0006, 0.0008, 0.0007, 0.0006, 0.0007, 0.0008, 0.0007,
#          0.0007, 0.0007, 0.0006, 0.0009, 0.0008, 0.0008],
#         [0.0008, 0.0008, 0.0007, 0.0009, 0.0009, 0.0008, 0.0007, 0.0006, 0.0006,
#          0.0007, 0.0006, 0.0006, 0.0006, 0.0008, 0.0007],
#         [0.0011, 0.0010, 0.0008, 0.0007, 0.0011, 0.0013, 0.0010, 0.0008, 0.0007,
#          0.0007, 0.0006, 0.0007, 0.0008, 0.0010, 0.0008],
#         [0.0009, 0.0010, 0.0009, 0.0007, 0.0008, 0.0013, 0.0011, 0.0008, 0.0007,
#          0.0007, 0.0006, 0.0009, 0.0008, 0.0008, 0.0007],
#         [0.0012, 0.0009, 0.0008, 0.0007, 0.0006, 0.0006, 0.0007, 0.0007, 0.0007,
#          0.0006, 0.0007, 0.0009, 0.0008, 0.0008, 0.0008],
#         [0.0011, 0.0008, 0.0005, 0.0006, 0.0006, 0.0007, 0.0008, 0.0007, 0.0007,
#          0.0006, 0.0006, 0.0007, 0.0010, 0.0012, 0.0008],
#         [0.0007, 0.0006, 0.0005, 0.0006, 0.0006, 0.0089, 0.0076, 0.0006, 0.0008,
#          0.0007, 0.0006, 0.0007, 0.0013, 0.0011, 0.0007],
#         [0.0009, 0.0008, 0.0007, 0.0008, 0.0008, 0.0107, 0.0089, 0.0008, 0.0009,
#          0.0006, 0.0007, 0.0009, 0.0009, 0.0007, 0.0007],
#         [0.0012, 0.0009, 0.0008, 0.0007, 0.0007, 0.0009, 0.0007, 0.0008, 0.0009,
#          0.0007, 0.0008, 0.0008, 0.0007, 0.0006, 0.0006],
#         [0.0009, 0.0006, 0.0006, 0.0006, 0.0007, 0.0008, 0.0008, 0.0008, 0.0008,
#          0.0009, 0.0008, 0.0008, 0.0007, 0.0006, 0.0007],
#         [0.0005, 0.0005, 0.0006, 0.0008, 0.0007, 0.0006, 0.0009, 0.0010, 0.0009,
#          0.0010, 0.0008, 0.0007, 0.0006, 0.0006, 0.0007],
#         [0.0008, 0.0007, 0.0006, 0.0009, 0.0008, 0.0006, 0.0007, 0.0012, 0.0011,
#          0.0009, 0.0008, 0.0007, 0.0006, 0.0008, 0.0009],
#         [0.0011, 0.0008, 0.0006, 0.0011, 0.0009, 0.0008, 0.0009, 0.0010, 0.0010,
#          0.0009, 0.0008, 0.0007, 0.0006, 0.0012, 0.0009]], device='cuda:0',
#        grad_fn=<SqueezeBackward0>)
# tensor([[False,  True,  True,  True,  True,  True, False,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True, False,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [False, False,  True,  True, False, False,  True,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True, False, False,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True, False, False,  True],
#         [ True,  True,  True,  True,  True, False, False,  True,  True,  True,
#           True,  True, False, False,  True],
#         [ True,  True,  True,  True,  True, False, False,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True, False,  True,  True,
#           True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True, False, False,  True,
#           True,  True,  True,  True,  True],
#         [False,  True,  True, False,  True,  True,  True, False, False,  True,
#           True,  True,  True, False,  True]], device='cuda:0')

# %%
#load previous model 
file_name = "model_L0_1.pt"
print(os.path.join(model_path, file_name))
model = torch.load(os.path.join(model_path, file_name))

n_filters = 1
std = 0.02
# model_this_space.deeper_op(std=std)

sum_total_decode = val_decoded + val_decoded_0_0[:,1:]

#make the filter be for the t+1 time
d1 = train_data_layer0[:,2:]

d2 = train_decoded_0_1 + train_decoded_0_0[:,1:]
loss = torch.mean((d1 - d2)**2, dim=(0,1), keepdim=True).to('cuda')
# print(loss)
loss_summary = apply_local_op(loss, device).squeeze()
resolved_map = loss_summary <= 0.001
model.resolved_maps[str(0)][str(1)] = resolved_map.float()

plt.imshow(resolved_map.cpu().detach().numpy())
model.wider_op(n_filters=n_filters, std=std)

print(encode(model,train_decoded_0_0[0].unsqueeze(1).to(device), 0).shape)

train_this = train_decoded_0_1 + train_decoded_0_0[:,1:]
val_this = val_decoded_0_1 + val_decoded_0_0[:,1:]
dataset = MultiScaleDynamicsDataSet(train_this[:,4].to('cuda'), val_this[:,4].to('cuda'), 
                                    train_data_layer0[:,6].to('cuda'), val_data_layer0[:,6].to('cuda'), n_levels=1)

train_data, val_data,_ = dataset.obtain_data_at_current_level(0)
print(train_data.shape)

model_this_space, val_losses, best_val_loss= train_arch(model, dataset, max_epoch=3000, batch_size=500, cur_level=0)
# Out:
# ../model/toy1_space/model_L0_1.pt
# torch.Size([499, 1, 15, 15])
# torch.Size([500, 1, 31, 31])
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# epoch [300/3000]:
# [training set] local: 0.0003/0.0301/0.0152
# [validation set] local: 0.0006/0.0016/0.0011
# epoch [600/3000]:
# [training set] local: 0.0005/0.0174/0.0090
# [validation set] local: 0.0010/0.0079/0.0044
# epoch [900/3000]:
# [training set] local: 0.0007/0.0137/0.0072
# [validation set] local: 0.0011/0.0181/0.0096
# epoch [1200/3000]:
# [training set] local: 0.0005/0.0137/0.0071
# [validation set] local: 0.0008/0.0188/0.0098
# epoch [1500/3000]:
# [training set] local: 0.0006/0.0135/0.0070
# [validation set] local: 0.0010/0.0197/0.0104
# epoch [1800/3000]:
# [training set] local: 0.0005/0.0136/0.0070
# [validation set] local: 0.0008/0.0191/0.0100
# epoch [2100/3000]:
# [training set] local: 0.0004/0.0136/0.0070
# [validation set] local: 0.0007/0.0191/0.0099
# epoch [2400/3000]:
# [training set] local: 0.0005/0.0135/0.0070
# [validation set] local: 0.0008/0.0194/0.0101
# epoch [2700/3000]:
# [training set] local: 0.0005/0.0134/0.0069
# [validation set] local: 0.0008/0.0194/0.0101
# epoch [3000/3000]:
# [training set] local: 0.0004/0.0135/0.0070
# [validation set] local: 0.0007/0.0193/0.0100

# %%
resovled_map_0_1 = model_this_space.resolved_maps[str(0)][str(1)]
print(resovled_map_0_1.shape)
plt.imshow(resovled_map_0_1.cpu().detach().numpy())
# Out:
# torch.Size([15, 15])

# %%
torch.save(model_this_space, os.path.join(model_path, "model_L0_2.pt"))

# %%
plt.imshow(train_this[0,0].cpu().detach().numpy())

# %%
# train_data = np.load('../data/toy1_train_data.npy')
# # val_data = np.load('../data/toy1_val_data.npy')
# train_data_this = obtain_data_at_current_level(torch.tensor(train_data[0]).unsqueeze(1).float(), 0,3)

train_data_this = torch.tensor(train_this[0]).unsqueeze(1).float().to('cuda')
# train_data, val_data,_ = dataset.obtain_data_at_current_level(0)
encoded = encode(model_this_space, train_data_this, 0)
plt.imshow(encoded[0,0].cpu().detach().numpy())
plt.title("encoded")
plt.colorbar()
plt.show()


decoded = decode(model_this_space, encoded, 0)
plt.imshow(decoded[0,0].cpu().detach().numpy())
plt.title("decoded")
plt.colorbar()
plt.show()

print(decoded.shape)
print(train_this.shape)
sum_total = decoded[:,0].to('cuda')+train_this[0].to('cuda')
plt.imshow(sum_total[0].cpu().detach().numpy())
plt.title("sum_total")
plt.colorbar()
plt.show()

forwarded,_,_,_ = model_this_space( train_data_this, 0)
plt.imshow(forwarded[0,0].cpu().detach().numpy())
plt.title("forward")
plt.colorbar()
plt.show()

# forwarded,_,_,_ = model_this_space( train_data_this, 0)
plt.imshow(train_data_this[0,0].cpu().detach().numpy())
plt.title('train_data_this')
plt.colorbar()
plt.show()

plt.imshow(train_data_layer0[0,2].cpu().detach().numpy())
plt.title('train_data_layer0')
plt.colorbar()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# torch.Size([498, 1, 31, 31])
# torch.Size([500, 498, 31, 31])

# %%
plt.plot(encoded[:,0,0,0].cpu().detach().numpy())
plt.plot(encoded[:,0,8,5].cpu().detach().numpy())
plt.plot(encoded[:,0,8,6].cpu().detach().numpy())
plt.plot(encoded[:,0,7,6].cpu().detach().numpy())
plt.plot(encoded[:,0,7,5].cpu().detach().numpy())

plt.plot(encoded[:,0,-1,-1].cpu().detach().numpy())

# %%
plt.plot(sum_total[:,12,18].cpu().detach().numpy())
plt.plot(train_data[0,2:,12,18])

# %%
train_data, val_data,_ = dataset.obtain_data_at_current_level(0)
print(train_data.shape)
plt.imshow(val_data[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()
predicted,_,_,_ = model_this_space(train_data, 0)
plt.imshow(predicted[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()

# plt.imshow(val_data[0,0].cpu().detach().numpy()+predicted[0,0].cpu().detach().numpy())
# plt.colorbar()
# plt.show()


plt.imshow(val_data_layer0[0,1].cpu().detach().numpy())
plt.colorbar()
plt.show()
# Out:
# torch.Size([500, 1, 31, 31])

# %%
encoded = encode(model_this_space, val_data_layer0[0].unsqueeze(1).to('cuda'), 0)
print(encoded.shape)

plt.imshow(encoded[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()

decoded = decode(model_this_space, encoded, 0)
print(decoded.shape)
plt.imshow(decoded[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()
plt.plot(encoded[:,0,9,5].cpu().detach().numpy())
# print(torch.log(encoded[:,0,0,0]))
plt.show()
# Out:
# torch.Size([500, 1, 15, 15])
# torch.Size([500, 1, 31, 31])

# %%
ones_predicted = encode(model_this_space, torch.ones((1,1,31,31)).to('cuda'), 0)
plt.imshow(ones_predicted[0,0].cpu().detach().numpy())
plt.colorbar()

# %%
plt.imshow(train_decoded_0_0[0,0].cpu().detach().numpy(), vmin=0.42, vmax=0.5)
plt.colorbar()
plt.show()

encoded_0_1 = encode(model_this_space, train_decoded_0_0[0].unsqueeze(1).to(device),0)
print(encoded_0_1.shape)
plt.plot(encoded_0_1[:,0,0,0].cpu().detach().numpy())
plt.plot(train_encoded_0_0[0,1:,0,0].cpu().detach().numpy())
plt.show()
decoded_0_1 = decode(model_this_space, encoded_0_1, 0)

plt.imshow(decoded_0_1[0,0].cpu().detach().numpy(),vmin=0.42, vmax=0.5)
plt.colorbar()
plt.show()

mse = np.mean(((decoded_0_1[:,0].cpu() - train_decoded_0_0[0].cpu())**2).cpu().detach().numpy(), axis=(1,2))
plt.plot(mse)
print("train_data_layer0 shape = ", train_data_layer0.shape)
print("train_decoded_0_0 shape = ", train_decoded_0_0.shape)
mse = np.mean(((train_data_layer0[0,1:].cpu() - train_decoded_0_0[0].cpu())**2).cpu().detach().numpy(), axis=(1,2))
plt.semilogy(mse, label = "layer 0")
print("decoded_0_1 shape = ", decoded_0_1.shape)
print("train_data_layer0[:,1:] shape = ", train_data_layer0[0,1:].shape)
mse = np.mean(((train_data_layer0[0,1:].cpu() - decoded_0_1[:,0].cpu())**2).cpu().detach().numpy(), axis=(1,2))
plt.plot(mse,label = "layer 1")
plt.title("mse")
plt.legend()

plt.show()
plt.imshow(train_data[0,0],vmin=0.42, vmax=0.5)
plt.colorbar()
plt.show()
# Out:
# torch.Size([499, 1, 15, 15])
# train_data_layer0 shape =  torch.Size([500, 500, 31, 31])
# train_decoded_0_0 shape =  torch.Size([500, 499, 31, 31])
# decoded_0_1 shape =  torch.Size([499, 1, 31, 31])
# train_data_layer0[:,1:] shape =  torch.Size([499, 31, 31])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c17d3b22e89d> in <module>()
#      28
#      29 plt.show()
# ---> 30 plt.imshow(train_data[0,0],vmin=0.42, vmax=0.5)
#      31 plt.colorbar()
#      32 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in set_data(self, A)
#     643                 self._A = pil_to_array(A)
#     644         else:
# --> 645             self._A = cbook.safe_masked_invalid(A, copy=True)
#     646
#     647         if (self._A.dtype != np.uint8 and
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#    1362
#    1363 def safe_masked_invalid(x, copy=False):
# -> 1364     x = np.array(x, subok=True, copy=copy)
#    1365     if not x.dtype.isnative:
#    1366         # Note that the argument to `byteswap` is 'inplace',
#
# ~/.local/lib/python3.6/site-packages/torch/_tensor.py in __array__(self, dtype)
#     676             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     677         if dtype is None:
# --> 678             return self.numpy()
#     679         else:
#     680             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
print(dataset.train_data.shape)
print(train_data_layer0[0].shape)
encoded_0_1 = encode(model_this_space, train_data_layer0[0].unsqueeze(1).to(device),0)

print(encoded.shape)
plt.imshow(encoded[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()

decoded_0_1 = decode(model_this_space, encoded, 0)

print(decoded.shape)
plt.imshow(decoded[0,0].cpu().detach().numpy(), vmin=0.4, vmax=0.5)
plt.colorbar()
plt.show()


print(train_data_layer0.shape)
plt.imshow(train_data_layer0[0,0].cpu().detach().numpy(), vmin=0.4, vmax=0.5)
plt.colorbar()
plt.show()


plt.plot(train_data_layer0[0,:,18,13].cpu().detach().numpy(), label = "truth")
plt.plot(decoded[:,0,18,13].cpu().detach().numpy(), label = "predicted")
plt.legend()
plt.xlim([0,100])

plt.show()

mse = np.mean(((decoded.cpu() - train_data_layer0[:,1:].cpu())**2).cpu().detach().numpy(), axis=(1,2,3))
plt.plot(mse)
plt.title("mse")

# %%
# #encode the data 
# model = models_space['model_L0_0']
n_train, n_timesteps, _,_ = train_data.shape
train_encoded = torch.zeros((n_train, n_timesteps, 15,15))
val_encoded = torch.zeros((len(val_data), n_timesteps, 15,15))
data = torch.tensor(train_data).unsqueeze(2).float()

val_data_layer0 = torch.zeros((len(val_data), n_timesteps, 31,31))
train_data_layer0 = torch.zeros((len(train_data), n_timesteps, 31,31))
for i in tqdm(range(len(train_data))):
    data_this = obtain_data_at_current_level(data[i], 0,3)
    train_data_layer0[i] = data_this[:,0]
    encoded = encode(model_this_space, data_this, 0)
    train_encoded[i] = encoded[:,0]

data = torch.tensor(val_data).unsqueeze(2).float()
for i in tqdm(range(len(val_data))):
    data_this = obtain_data_at_current_level(data[i], 0,3)
#     print(data_this.shape)
    val_data_layer0[i] = data_this[:,0]
    encoded = encode(model_this_space, data_this, 0)
    val_encoded[i] = encoded[:,0]

# %%
#need to do the next time training part

#doing the time training
print("inside train_one_timestep")
i=None
j=None
step_size = 8
dt=1
n_forward = 5
arch = [225, 225*2, 225*2, 225*2, 225]
batch_size = 500
lr = 0.001

model_name = 'model_L0_1_{}.pt'.format(step_size)#{}_D{}_noise{}.pt'.format(current_size, step_size, noise)
model_path_this = os.path.join(model_path, model_name)

dataset = utils.DataSet(train_encoded.flatten(start_dim=2), val_encoded.flatten(start_dim=2), val_encoded.flatten(start_dim=2), dt, step_size, n_forward)

print(dataset.train_x.shape)
print(dataset.train_ys.shape)
print('create model {} ...'.format(model_name))
model = tnet.ResNet(arch=arch, dt=dt, step_size=step_size)

# # training
model.train_net(dataset, max_epoch=30000, batch_size=batch_size, lr=lr,
            model_path=os.path.join(model_path, model_name))


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# load models
step_sizes = [4,8]
models_time = list()
for step_size in step_sizes:
    print('model_L0_1_{}.pt'.format(step_size))
    models_time.append(torch.load(os.path.join(model_path,'model_L0_1_{}.pt'.format(step_size)),map_location='cpu'))
#     models.append(torch.load(os.path.join(model_path, 'model_D{}_noise0.0.pt'.format(step_size)), map_location='cpu'))

# fix model consistencies trained on gpus (optional)
for model in models_time:
    model.device = 'cpu'
    model._modules['increment']._modules['activation'] = torch.nn.ReLU()
    
# uniscale time-stepping with NN
preds_mse = list()
times = list()

# test_data = val_data
ks = [1]
n_steps = val_encoded.shape[1] - 1
t = [dt*(step+1) for step in range(n_steps)]
criterion = torch.nn.MSELoss(reduction='none')

test_data = torch.tensor(val_encoded).flatten(start_dim=2).float()
print(test_data.shape)

n_steps = 499
for model in tqdm(models_time):
#     start = time.time()
    print("val_encoded.shape = ", val_encoded.shape)
    print("shape that will be passed in = ", torch.tensor(val_encoded[:, 0, :]).flatten(start_dim=1).float().shape)
    y_preds = model.uni_scale_forecast(torch.tensor(val_encoded[:, 0, :]).flatten(start_dim=1).float(), n_steps=n_steps)
#     end = time.time()
#     times.append(end - start)
    preds_mse.append(criterion(torch.tensor(val_encoded[:, 1:, :]).flatten(start_dim=2).float(), y_preds).mean(-1))
    for i in range(1):
        plt.plot(y_preds[1,:,i], label="predicted")
        plt.plot(test_data[1, 1:, i].detach().numpy(),label="Truth")
        x = y_preds[1,::model.step_size,i]
        
#         plt.plot(np.arange(len(x))*model.step_size,x, '.k')
#     plt.xlim([0,200])
    plt.legend()
    plt.title("step size = "+ str(model.step_size))
    plt.show()
    
# visualize forecasting error at each time step    
fig = plt.figure(figsize=(20, 8))
colors=iter(plt.cm.rainbow(np.linspace(0, 1, len(step_sizes))))
for k in range(len(preds_mse)):
    err = preds_mse[k]
    mean = err.mean(0).detach().numpy()
    rgb = next(colors)
    plt.plot(t, np.log10(mean), linestyle='-', color=rgb, linewidth=3.0, label='$\Delta\ t$={}'.format(step_sizes[k]*dt))
plt.legend(fontsize=20, loc='upper right')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# %%
#next, we need to decode

# %%
#for next layer, we are going to have val_decoded as input and val_data_layer0 as output

print(train_decoded[:,0].shape)
print(val_decoded[:,0].shape)
dataset = MultiScaleDynamicsDataSet(train_decoded[:,0].to('cuda'), val_decoded[:,0].to('cuda'), 
                                    train_data_layer0[:,0].to('cuda'), val_data_layer0[:,0].to('cuda'), n_levels=1)

# # training in space
archs = [[1]]#,3,4],[1,2,3,4],[1,3,5,7]]
tols = [ 0.001]#, 0.0005, 0.0001]
net.train_net(archs=archs, dataset=dataset, max_epoch=2000, batch_size=350, 
              tols=tols, activation=torch.nn.Sequential(), w=0.5, model_path=model_path, 
              result_path=result_path, std=0.01, verbose=2)

# %%
#load all models (don't actually need all of them)

# trained models at different levels
models_space = {}
print('model names: model_L{level}_{index}')
for file_name in sorted(os.listdir(model_path)):
    model_name, _ = file_name.split('.')
    print(model_name)
    models_space[model_name] = torch.load(os.path.join(model_path, file_name))

# %%
model = models_space['model_L0_0']

data = torch.tensor(train_data[0]).unsqueeze(1).float()
print(data.shape)
data_this = obtain_data_at_current_level(data, 0,3)

print(train_decoded[:,0:1].shape)
forwarded,_,_,_ = model.forward(train_decoded[0].unsqueeze(1).to('cuda'), 0)

# %%
print(forwarded.shape)

plt.imshow(forwarded[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()

plt.imshow(train_decoded[0,0].cpu().detach().numpy())
plt.colorbar()
plt.show()

# %%
plt.plot(forwarded[:,0,0,0].cpu().detach().numpy())
plt.plot(train_decoded[0,:,0,0].cpu().detach().numpy())
# plt.colorbar()
plt.show()

# %%
# plt.plot(val_decoded[0,:,12,18].cpu().detach().numpy())
# plt.plot(val_data_layer0[0,1:,12,18].cpu().detach().numpy())

plt.plot(val_decoded[0,:,18,12].cpu().detach().numpy())
plt.plot(val_data_layer0[0,1:,18,12].cpu().detach().numpy())
plt.show()

plt.imshow(val_data_layer0[0,0])
plt.colorbar()

# %%
plt.plot(train_decoded[0,:,12,18].cpu().detach().numpy())
print(train_decoded.shape)
print(data_this.shape)
data = torch.tensor(train_data[0]).unsqueeze(1).float()
print(data.shape)
data_this = obtain_data_at_current_level(data, 0,3)
plt.plot(data_this[:,0, 12, 18].cpu().detach().numpy())

# %%
#animate the first decoded

def animate(snapshots, normalize = True, file_name = "animation.gif"):
    """
    Makes an animation of snapshots in time
    
    inputs:
    snapshots: np.array of size (n_time_steps,1, dim, dim)
    normalize = True: whether to fix axis between 0 and 1 or not
    file_name = "animation.gif": file name of where to save gif
    
    outputs:
    no returned output
    gif saved to file_name
    """


    fps = 30
    nSeconds = len(snapshots)/fps
    
    # First set up the figure, the axis, and the plot element we want to animate
    fig = plt.figure( figsize=(8,8) )

    a = snapshots[0,:,:,:][0].T
    if normalize:
        im = plt.imshow(a, interpolation='none', aspect='auto', vmin=0.0, vmax=1.0)
    else:
        im = plt.imshow(a, interpolation='none', aspect='auto', vmin=np.min(snapshots), vmax=np.max(snapshots))
    plt.colorbar()

    print("Animating, may take a little while...")

    def animate_func(i):
        if i % fps == 0:
            print( '.', end ='' )

        im.set_array(snapshots[i,:,:,:,][0].T)
        return [im]

    anim = animation.FuncAnimation(
                                   fig,
                                   animate_func,
                                   frames = int(nSeconds * fps),
                                   interval = 1000 / fps, # in ms
                                   )
    writergif = animation.PillowWriter(fps=30)
    anim.save(file_name, writer=writergif)

    print('Done! gif saved to ', file_name)
    
to_animate = val_decoded[0].unsqueeze(1).cpu().detach().numpy()
animate(to_animate, False, 'decoded_0_0.gif')

# %%
val_decoded[0].unsqueeze(1).shape
