# %% [markdown]
# # toy problem 2

# %% [markdown]
# ## Generate data
#
# train_data size (100,500,128,128)
#
# validation size (10,500,128,128)
#
# test size (10,500,128,128)

# %%
import os
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
def make_data(n_points, file_name, data_dir = './data/toy2', n_time_steps = 500, dim = 128, num_periods_big = 8, w0=0.5, w1=1.0, width_small = 64):
    """
    Makes data for toy2a
    
    Inputs:
    n_points: int, how many data points 
    file_name: str, name of file to save
    data_dir = './data/toy2': str, directory of where to store
    n_time_steps = 500: int, how many time steps per data point
    dim = 128: int, how many data points per dim, while be same in both x and y directions
    num_periods_big = 8: int, how many periods of the slow scale
    w0 = 0.5: float, frequency of slow scale
    w1 = 1.0: float, frequency of fast scale
    width_small = 8: width of small (fast) scale
    
    Output: 
    data: size (n_points,n_time_steps,dim, dim) will be returned and saved to file data_dir+file_name
    
    """
    print(width_small)
    print("Making data")
    x = np.arange(dim)
    y = np.arange(dim)
    data = np.zeros((n_points, n_time_steps, dim, dim))

    for i in tqdm(range(n_points)):
        t_start = np.random.uniform(high=4*np.pi)
        t = np.linspace(t_start, num_periods_big*4*np.pi + t_start, n_time_steps)


        xgrid, ygrid, tgrid = np.meshgrid(x, y, t)

        Phi = np.cos(w0*tgrid)

        Phi[:width_small, :width_small,:] = np.cos(w1*tgrid[:width_small, :width_small,:]+np.pi/4)
        scaled_Phi = (Phi.T - Phi.min()) / (Phi.max() - Phi.min())
        data[i] = scaled_Phi

    print("making done, saving to ", os.path.join(data_dir, file_name))
    np.save(os.path.join(data_dir, file_name), data)
    print("done")
    
    return data

# %%
n_train_points = 100
n_val_points = 10
n_test_points = 10
n_time_steps = 500
dim = 16
width_small = int(dim/4)

# params
w0 = 0.5
w1 = 1.0
# width_small = 8
num_periods_big = 8


# paths
data_dir = './data/toy2b'
result_dir = './result/toy2b'


x = np.arange(dim)
y = np.arange(dim)
train_data = make_data(n_train_points, 'train_data.npy', data_dir = data_dir,width_small=width_small,dim=dim) 
print(train_data.shape)
plt.imshow(train_data[0,0])
plt.colorbar()
plt.show()
val_data = make_data(n_val_points, 'val_data.npy', data_dir = data_dir,width_small=width_small,dim=dim) 
test_data = make_data(n_test_points, 'test_data.npy', data_dir=data_dir,width_small=width_small,dim=dim)
# Out:
# 4
# Making data
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# making done, saving to  ./data/toy2b\train_data.npy
# done
# (100, 500, 16, 16)
# 4
# Making data
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# making done, saving to  ./data/toy2b\val_data.npy
# done
# 4
# Making data
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# making done, saving to  ./data/toy2b\test_data.npy
# done

# %%
print(train_data.shape)
plt.imshow(train_data[2,0])
plt.colorbar()
# Out:
# (100, 500, 8, 8)

# %%
def animate(snapshots, normalize = True, file_name = "animation.gif"):
    """
    Makes an animation of snapshots in time
    
    inputs:
    snapshots: np.array of size (n_time_steps,1, dim, dim)
    normalize = True: whether to fix axis between 0 and 1 or not
    file_name = "animation.gif": file name of where to save gif
    
    outputs:
    no returned output
    gif saved to file_name
    """


    fps = 30
    nSeconds = len(snapshots)/fps
    
    # First set up the figure, the axis, and the plot element we want to animate
    fig = plt.figure( figsize=(8,8) )

    a = snapshots[0,:,:,:][0].T
    if normalize:
        im = plt.imshow(a, interpolation='none', aspect='auto', vmin=0.0, vmax=1.0)
    else:
        im = plt.imshow(a, interpolation='none', aspect='auto', vmin=np.min(snapshots), vmax=np.max(snapshots))
    plt.colorbar()

    print("Animating, may take a little while...")

    def animate_func(i):
        if i % fps == 0:
            print( '.', end ='' )

        im.set_array(snapshots[i,:,:,:,][0].T)
        return [im]

    anim = animation.FuncAnimation(
                                   fig,
                                   animate_func,
                                   frames = int(nSeconds * fps),
                                   interval = 1000 / fps, # in ms
                                   )
    writergif = animation.PillowWriter(fps=30)
    anim.save(file_name, writer=writergif)

    print('Done! gif saved to ', file_name)

# %%
animate(train_data[0].reshape(n_time_steps,1, dim, dim), file_name = os.path.join(result_dir,'train_data.gif'))
# Out:
# Animating, may take a little while...
# ..
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 251, in saving
#     yield self
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1141, in save
#     anim._draw_next_frame(d, blit=False)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1177, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1202, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2012, in draw_idle
#     self.draw(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 1169, in draw
#     tick.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 291, in draw
#     artist.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\text.py", line 725, in draw
#     textrenderer.draw_text(gc, x, y, clean_line,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 195, in draw_text
#     font = self._get_agg_font(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 272, in _get_agg_font
#     fname = findfont(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\font_manager.py", line 1314, in findfont
#     return os.path.realpath(filename)
#   File "C:\Users\16kat\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-4e619ad7cffb>", line 1, in <module>
#     animate(train_data[0].reshape(n_time_steps,1, dim, dim), file_name = os.path.join(result_dir,'train_data.gif'))
#   File "<ipython-input-5-2e1703cf0959>", line 45, in animate
#     anim.save(file_name, writer=writergif)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 253, in saving
#     self.finish()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 554, in finish
#     self._frames[0].save(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\PIL\Image.py", line 2148, in save
#     fp = builtins.open(filename, "w+b")
# FileNotFoundError: [Errno 2] No such file or directory: './result/toy2a\\train_data.gif'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\16kat\anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 251, in saving
#     yield self
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1141, in save
#     anim._draw_next_frame(d, blit=False)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1177, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1202, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2012, in draw_idle
#     self.draw(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 1169, in draw
#     tick.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 291, in draw
#     artist.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\text.py", line 725, in draw
#     textrenderer.draw_text(gc, x, y, clean_line,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 195, in draw_text
#     font = self._get_agg_font(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 272, in _get_agg_font
#     fname = findfont(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\font_manager.py", line 1314, in findfont
#     return os.path.realpath(filename)
#   File "C:\Users\16kat\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-4e619ad7cffb>", line 1, in <module>
#     animate(train_data[0].reshape(n_time_steps,1, dim, dim), file_name = os.path.join(result_dir,'train_data.gif'))
#   File "<ipython-input-5-2e1703cf0959>", line 45, in animate
#     anim.save(file_name, writer=writergif)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 253, in saving
#     self.finish()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 554, in finish
#     self._frames[0].save(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\PIL\Image.py", line 2148, in save
#     fp = builtins.open(filename, "w+b")
# FileNotFoundError: [Errno 2] No such file or directory: './result/toy2a\\train_data.gif'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\16kat\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 251, in saving
#     yield self
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1141, in save
#     anim._draw_next_frame(d, blit=False)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1177, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1202, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2012, in draw_idle
#     self.draw(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 1169, in draw
#     tick.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 291, in draw
#     artist.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\text.py", line 725, in draw
#     textrenderer.draw_text(gc, x, y, clean_line,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 195, in draw_text
#     font = self._get_agg_font(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 272, in _get_agg_font
#     fname = findfont(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\font_manager.py", line 1314, in findfont
#     return os.path.realpath(filename)
#   File "C:\Users\16kat\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-4e619ad7cffb>", line 1, in <module>
#     animate(train_data[0].reshape(n_time_steps,1, dim, dim), file_name = os.path.join(result_dir,'train_data.gif'))
#   File "<ipython-input-5-2e1703cf0959>", line 45, in animate
#     anim.save(file_name, writer=writergif)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 253, in saving
#     self.finish()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 554, in finish
#     self._frames[0].save(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\PIL\Image.py", line 2148, in save
#     fp = builtins.open(filename, "w+b")
# FileNotFoundError: [Errno 2] No such file or directory: './result/toy2a\\train_data.gif'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1211, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\16kat\anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x000001E2C30F44C0> (for post_execute):
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 251, in saving
#     yield self
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1141, in save
#     anim._draw_next_frame(d, blit=False)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1177, in _draw_next_frame
#     self._post_draw(framedata, blit)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1202, in _post_draw
#     self._fig.canvas.draw_idle()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2012, in draw_idle
#     self.draw(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 1169, in draw
#     tick.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 291, in draw
#     artist.draw(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\text.py", line 725, in draw
#     textrenderer.draw_text(gc, x, y, clean_line,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 195, in draw_text
#     font = self._get_agg_font(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 272, in _get_agg_font
#     fname = findfont(prop)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\font_manager.py", line 1314, in findfont
#     return os.path.realpath(filename)
#   File "C:\Users\16kat\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-4e619ad7cffb>", line 1, in <module>
#     animate(train_data[0].reshape(n_time_steps,1, dim, dim), file_name = os.path.join(result_dir,'train_data.gif'))
#   File "<ipython-input-5-2e1703cf0959>", line 45, in animate
#     anim.save(file_name, writer=writergif)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 1145, in save
#     writer.grab_frame(**savefig_kwargs)
#   File "C:\Users\16kat\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 253, in saving
#     self.finish()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\animation.py", line 554, in finish
#     self._frames[0].save(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\PIL\Image.py", line 2148, in save
#     fp = builtins.open(filename, "w+b")
# FileNotFoundError: [Errno 2] No such file or directory: './result/toy2a\\train_data.gif'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'FileNotFoundError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3338, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3435, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2923, in _run_cell
#     return runner(coro)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3146, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3357, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1211, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2877, in run_cell
#     result = self._run_cell(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2928, in _run_cell
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2047, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1436, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1336, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1211, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1151, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\events.py", line 89, in trigger
#     func(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py", line 121, in flush_figures
#     return show(True)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py", line 41, in show
#     display(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\display.py", line 313, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\formatters.py", line 180, in format
#     data = formatter(obj)
#   File "<decorator-gen-2>", line 2, in __call__
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\formatters.py", line 224, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\formatters.py", line 341, in __call__
#     return printer(obj)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\pylabtools.py", line 248, in <lambda>
#     png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\pylabtools.py", line 132, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\backend_bases.py", line 2195, in print_figure
#     bbox_inches = self.figure.get_tightbbox(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\figure.py", line 2506, in get_tightbbox
#     bbox = a.get_tightbbox(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 4155, in get_tightbbox
#     bb_xaxis = self.xaxis.get_tightbbox(
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 1111, in get_tightbbox
#     self._update_label_position(renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 2058, in _update_label_position
#     bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 2042, in _get_tick_boxes_siblings
#     ticks_to_draw = axx.xaxis._update_ticks()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\axis.py", line 1022, in _update_ticks
#     major_labels = self.major.formatter.format_ticks(major_locs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\ticker.py", line 249, in format_ticks
#     self.set_locs(values)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\ticker.py", line 780, in set_locs
#     self._compute_offset()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\matplotlib\ticker.py", line 793, in _compute_offset
#     lmin, lmax = locs.min(), locs.max()
#   File "C:\Users\16kat\anaconda3\lib\site-packages\numpy\core\_methods.py", line 43, in _amin
#     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\16kat\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\16kat\anaconda3\lib\inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\16kat\anaconda3\lib\ntpath.py", line 664, in realpath
#     if _getfinalpathname(spath) == path:
# KeyboardInterrupt
