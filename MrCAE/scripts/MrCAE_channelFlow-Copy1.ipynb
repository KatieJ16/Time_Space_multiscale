# %% [markdown]
# ## JHU channel flow

# %% [markdown]
# ### Created by Yuying Liu, 12/03/2019

# %%
# imports
import os
# import cv2
import sys
import torch
import pickle
# import pyJHTDB
import numpy as np
from scipy.linalg import svd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import h5py

from matplotlib import animation
from IPython.display import HTML

# %matplotlib notebook
# %matplotlib inline

module_path = os.path.abspath(os.path.join('../src/'))
data_path = (os.path.join('../data/channel/'))

if module_path not in sys.path:
    sys.path.append(module_path)
    
import torch_cae_multilevel_V4 as net

# %%
hf = h5py.File('./channel.h5', 'r')
print(hf)
# Out:
# <HDF5 file "channel.h5" (mode r)>

# %%
data = hf.get('Velocity_0001').value 
print(data)

print(hf.get('xcoor').value )

list(hf.keys())
# Out:
# [[[[ 0.0000000e+00  0.0000000e+00  8.7506487e-20]
#    [ 0.0000000e+00  0.0000000e+00  6.1376743e-20]
#    [ 0.0000000e+00  0.0000000e+00 -8.2470708e-20]]
#
#   [[ 1.2946985e-02  3.4218094e-05 -2.8768179e-03]
#    [ 1.1174863e-02  4.0766132e-05  3.1946315e-03]
#    [ 1.0855857e-02  4.2192318e-05  3.3009108e-03]]
#
#   [[ 5.9254821e-02  7.3629897e-04 -7.7448091e-03]
#    [ 5.2635022e-02  8.3416683e-04  1.5915118e-02]
#    [ 5.1846910e-02  8.6593232e-04  1.3551293e-02]]]]
# [0.         0.04908739 0.09817477]
# <ipython-input-13-78ad50ec7b47>:1: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   data = hf.get('Velocity_0001').value
# <ipython-input-13-78ad50ec7b47>:4: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   print(hf.get('xcoor').value )
# ['Velocity_0001',
#  'Velocity_0002',
#  'Velocity_0003',
#  'Velocity_0004',
#  'Velocity_0005',
#  'Velocity_0006',
#  'xcoor',
#  'ycoor',
#  'zcoor']

# %%
dt = 0.0065
x = np.linspace(0, 25.9935, 500)/dt

n_times = 21
t=np.arange(0,8*n_times, 8)*dt
print(t)
# Out:
# [0.    0.052 0.104 0.156 0.208 0.26  0.312 0.364 0.416 0.468 0.52  0.572
#  0.624 0.676 0.728 0.78  0.832 0.884 0.936 0.988 1.04 ]

# %%
#read in from output files
# (data_points, dim) =  np.genfromtxt(os.path.join(data_path, 'output (0).csv'), delimiter=',', skip_header=1).shape
data_points = 4096
dim = 3
output = np.zeros((data_points, n_times))
for i in range(n_times):
    this = np.genfromtxt(os.path.join(data_path, 'output ('+str(i)+').csv'), delimiter=',', skip_header=1)
    output[:, i] =  this[:,0]
print(output.shape)
# Out:
# (4096, 21)

# %%
# print(output[:,1,0].reshape(nx, ny).shape)

nx = 128
ny = 32

plt.imshow(output[:,1].reshape(nx, ny).T)

# %%
# animation of raw_data
def plot_images(img_list):
    def init():
        img.set_data(img_list[0].reshape(nx, ny).T)
        return (img,)
    def animate(i):
        img.set_data(img_list[i].reshape(nx, ny).T)
        return (img,)

#     print(len(img_list[0,:,0]))
    fig = plt.figure(figsize=(15, 6))
    plt.axis('off')
    ax = fig.gca()
    img = ax.imshow(img_list[0].reshape(nx, ny).T, cmap='hot')
    plt.close();
    anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(img_list), interval=20, blit=True)
    return anim

imgs = np.array([output[:, i] for i in range(n_times)])
print(np.array(imgs).shape)

HTML(plot_images(imgs).to_jshtml())
# Out:
# (21, 4096)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgaaa40795447f4750ba9a132c793fe7a4">
#   <div class="anim-controls">
#     <input id="_anim_slideraaa40795447f4750ba9a132c793fe7a4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animaaa40795447f4750ba9a132c793fe7a4.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="animaaa40795447f4750ba9a132c793fe7a4.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="animaaa40795447f4750ba9a132c793fe7a4.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="animaaa40795447f4750ba9a132c793fe7a4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="animaaa40795447f4750ba9a132c793fe7a4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="animaaa40795447f4750ba9a132c793fe7a4.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="animaaa40795447f4750ba9a132c793fe7a4.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="animaaa40795447f4750ba9a132c793fe7a4.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="animaaa40795447f4750ba9a132c793fe7a4.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="animaaa40795447f4750ba9a132c793fe7a4.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selectaaa40795447f4750ba9a132c793fe7a4"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_aaa40795447f4750ba9a132c793fe7a4"
#              >
#       <label for="_anim_radio1_aaa40795447f4750ba9a132c793fe7a4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_aaa40795447f4750ba9a132c793fe7a4"
#              checked>
#       <label for="_anim_radio2_aaa40795447f4750ba9a132c793fe7a4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_aaa40795447f4750ba9a132c793fe7a4"
#              >
#       <label for="_anim_radio3_aaa40795447f4750ba9a132c793fe7a4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgaaa40795447f4750ba9a132c793fe7a4";
#     var slider_id = "_anim_slideraaa40795447f4750ba9a132c793fe7a4";
#     var loop_select_id = "_anim_loop_selectaaa40795447f4750ba9a132c793fe7a4";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAA0s0lEQVR4nO3dfcxmaV0f8N/THYYOOwz3wvKyDi/PsrAsLC4TFgG7VqpbpYiW\
# KNFGKTU11Zqm1djGtDH9o6mJTdrUxpi+mKY2WK3BhlZUtIhoFwsFBMIiL8vKwoCOK+siN8suW9Zd\
# nv7d5Pl+cU5Jdy7y+fx5nfzuc+5zrnOde37z5HwPjo6OBgAAAGBlf+7hPgAAAACA/1caHAAAAMDy\
# NDgAAACA5WlwAAAAAMvT4AAAAACWp8

# %%
U, s, VT = svd(output, full_matrices=False)
# reduced_data = U[:, :n_keep].dot(np.diag(s[:n_keep]).dot(VT[:n_keep, :])).reshape(449, 199, -1)
# coord_dynamics = VT[:n_keep, :]
# np.save(os.path.join(data_dir, 'data_'+str(n_keep)+'.npy'), coord_dynamics)

# %%
plt.semilogy(s)
plt.show()

# %%
print(U.shape)
fig, axs = plt.subplots(3,3, figsize=(20, 10))
# axs.type
# for i, ax in enumerate(axs):
for i, ax in enumerate(axs.ravel()):
    plot = U[:,i].T.reshape(ny, nx)
    ax.imshow(plot)
# Out:
# (4096, 21)

# %%
n_keep = 5
print(U.shape)
reduced_data = U[:, :n_keep].dot(np.diag(s[:n_keep]).dot(VT[:n_keep, :])).reshape(nx* ny, -1)
coord_dynamics = VT[:n_keep, :]
np.save(os.path.join(data_path, 'data_'+str(n_keep)+'.npy'), coord_dynamics)
# plt.imshow(reduced_data[:,0].reshape(nx, ny))

imgs = np.array([reduced_data[:, i] for i in range(n_times)])
print(np.array(imgs).shape)

HTML(plot_images(imgs).to_jshtml())
# Out:
# (4096, 21)
# (21, 4096)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb36c9f9f4954447189925e7e57872392">
#   <div class="anim-controls">
#     <input id="_anim_sliderb36c9f9f4954447189925e7e57872392" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb36c9f9f4954447189925e7e57872392.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="animb36c9f9f4954447189925e7e57872392.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="animb36c9f9f4954447189925e7e57872392.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="animb36c9f9f4954447189925e7e57872392.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="animb36c9f9f4954447189925e7e57872392.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="animb36c9f9f4954447189925e7e57872392.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="animb36c9f9f4954447189925e7e57872392.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="animb36c9f9f4954447189925e7e57872392.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="animb36c9f9f4954447189925e7e57872392.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="animb36c9f9f4954447189925e7e57872392.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_selectb36c9f9f4954447189925e7e57872392"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b36c9f9f4954447189925e7e57872392"
#              >
#       <label for="_anim_radio1_b36c9f9f4954447189925e7e57872392">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b36c9f9f4954447189925e7e57872392"
#              checked>
#       <label for="_anim_radio2_b36c9f9f4954447189925e7e57872392">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b36c9f9f4954447189925e7e57872392"
#              >
#       <label for="_anim_radio3_b36c9f9f4954447189925e7e57872392">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb36c9f9f4954447189925e7e57872392";
#     var slider_id = "_anim_sliderb36c9f9f4954447189925e7e57872392";
#     var loop_select_id = "_anim_loop_selectb36c9f9f4954447189925e7e57872392";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAzgElEQVR4nO3db+x2d10f8M/Plhtra7kK5YZyS/vDYouUwT1BQVA7RcImUeK/\
# mTkXN010T+YD57Jky7bEB1viExOXuGi2+W+66CaGOeYYgkGFUQZYELDtCvyKFKG29GpprS0tvz3Y\
# oyXX+633WbP2616vh9+Tz3Wd65zv+Z5zf+5fzvvo9PR0AAAAAFb2BU/0DgAAAAD839LgAAAAAJan\
# wQEAAAAsT4MDAAAAWJ4GBwAAALA8DQ

# %%
if os.path.exists('../data/npy/channel_flow2.npy'):
    data = np.load('../data/npy/channel_flow2.npy')
else:
#     # load shared library
#     lTDB = pyJHTDB.libJHTDB()
#     #initialize webservices
#     lTDB.initialize()

#     # add token
#     auth_token  = "edu.jhu.pha.turbulence.testing-201406"  # get ur own token from: http://turbulence.pha.jhu.edu/authtoken.aspx
#     lTDB.add_token(auth_token)
    
    # info
    n = 3
#     info = pyJHTDB.dbinfo.channel
#     name = info['name']
    x_sample_factor = 16
    y_sample_factor = 16
    nx = 2048 // x_sample_factor
    ny = 512 // y_sample_factor
    xnodes = np.linspace(0,8*np.pi, nx)#info['xnodes'][::x_sample_factor]
    ynodes = np.linspace(-1, 1, ny)#info['ynodes'][::y_sample_factor]
    zmid = 1.5*np.pi
    
    lpoints = []
    for i in range(nx):
        for j in range(ny):
            lpoints.append([xnodes[i], ynodes[j], zmid])
            
    points = np.array(lpoints, dtype='float32')
    
    np.savetxt("points.csv", points, delimiter=",")
    
    data = []
#     time = range(4000)
#     for t in info['time'][::8]:
#         sample = lTDB.getData(t, points, data_set = name, getFunction = 'getVelocity')
#         sample = np.reshape(sample, (nx, ny, n))
#         print('time t: ', t, ', sample shape: ', sample.shape)
#         data.append(sample)
    
#     data = np.stack(data, 0)
#     Phi = np.squeeze(data[:, :-1, :-1, 0])
#     data = (Phi - Phi.min()) / (Phi.max() - Phi.min())
#     np.save('../data/npy/channel_flow.npy', data)
    
# # viz
# plt.figure(figsize=(5, 10))
# plt.imshow(data[1, :, :])
# plt.title('sampled snapshot',fontsize=20)

# %%
# init model & load data
data_path = '../data/npy/channel_flow2.npy'
model_path = '../model/fluid2/'
result_path = '../result/fluid2/'

dataset = net.MultiScaleDynamicsDataSet(data_path, n_levels=4)

# %%
# training
archs = [[1,2,3,4,5],[1,3,5,7,9],[1,4,7,10,13],[1,6,11,16,21]]
tols = [0.02, 0.01, 0.008, 0.005]
net.train_net(archs=archs, dataset=dataset, max_epoch=4000, batch_size=350, tols=tols, activation=torch.nn.Sequential(), 
              w=0.5, model_path=model_path, result_path=result_path, std=0.01, verbose=2)
# Out:
# # of filters in each group:  [1, 1, 1, 1]
# *************************************************
# Model @Level 0:
# Perform deepening & widening, train each architectures ...
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0184/0.0555/0.0369, global: 0.0571/0.5384/0.2977
# [validation set] local: 0.0187/0.0605/0.0396, global: 0.0573/0.5440/0.3007
# epoch [500/5000]:
# [training set] local: 0.0066/0.0139/0.0102, global: 0.0300/0.3595/0.1948
# [validation set] local: 0.0066/0.0147/0.0107, global: 0.0302/0.3636/0.1969
# early stopping at 500th iteration due to satisfying reconstruction!
#
# -------------------------------------------------
# *************************************************
# # of filters in each group:  [2, 2, 2, 2]
# *************************************************
# Model @Level 1:
# Perform deepening & widening, train each architectures ...
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0214/0.1595/0.0905, global: 0.0411/0.4438/0.2424
# [validation set] local: 0.0217/0.1690/0.0954, global: 0.0412/0.4490/0.2451
# /usr/lib/python3/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type CAE. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/lib/python3/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/lib/python3/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2dBlock. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/lib/python3/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/lib/python3/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /usr/lib/python3/dist-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ConvTranspose2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# epoch [500/5000]:
# [training set] local: 0.0172/0.0317/0.0245, global: 0.0220/0.1881/0.1050
# [validation set] local: 0.0173/0.0365/0.0269, global: 0.0220/0.1899/0.1059
# epoch [1000/5000]:
# [training set] local: 0.0159/0.0305/0.0232, global: 0.0216/0.1880/0.1048
# [validation set] local: 0.0160/0.0352/0.0256, global: 0.0217/0.1917/0.1067
# epoch [1500/5000]:
# [training set] local: 0.0152/0.0294/0.0223, global: 0.0217/0.2057/0.1137
# [validation set] local: 0.0152/0.0329/0.0241, global: 0.0218/0.2092/0.1155
# epoch [2000/5000]:
# [training set] local: 0.0144/0.0291/0.0217, global: 0.0219/0.2268/0.1243
# [validation set] local: 0.0145/0.0333/0.0239, global: 0.0220/0.2302/0.1261
# epoch [2500/5000]:
# [training set] local: 0.0143/0.0275/0.0209, global: 0.0216/0.2217/0.1216
# [validation set] local: 0.0144/0.0321/0.0232, global: 0.0216/0.2261/0.1239
# epoch [3000/5000]:
# [training set] local: 0.0138/0.0270/0.0204, global: 0.0212/0.2248/0.1230
# [validation set] local: 0.0139/0.0316/0.0228, global: 0.0213/0.2263/0.1238
# epoch [3500/5000]:
# [training set] local: 0.0135/0.0265/0.0200, global: 0.0210/0.2253/0.1231
# [validation set] local: 0.0136/0.0316/0.0226, global: 0.0211/0.2265/0.1238
# epoch [4000/5000]:
# [training set] local: 0.0133/0.0264/0.0199, global: 0.0208/0.2241/0.1224
# [validation set] local: 0.0134/0.0304/0.0219, global: 0.0208/0.2235/0.1222
# epoch [4500/5000]:
# [training set] local: 0.0132/0.0265/0.0198, global: 0.0205/0.2270/0.1238
# [validation set] local: 0.0133/0.0304/0.0219, global: 0.0206/0.2264/0.1235
# epoch [5000/5000]:
# [training set] local: 0.0129/0.0257/0.0193, global: 0.0204/0.2257/0.1231
# [validation set] local: 0.0130/0.0311/0.0220, global: 0.0204/0.2257/0.1231
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0130/0.0257/0.0193, global: 0.0204/0.2255/0.1229
# [validation set] local: 0.0130/0.0309/0.0220, global: 0.0204/0.2254/0.1229
# epoch [500/5000]:
# [training set] local: 0.0075/0.0195/0.0135, global: 0.0150/0.2087/0.1119
# [validation set] local: 0.0076/0.0234/0.0155, global: 0.0150/0.2089/0.1120
# epoch [1000/5000]:
# [training set] local: 0.0063/0.0189/0.0126, global: 0.0132/0.1969/0.1051
# [validation set] local: 0.0063/0.0200/0.0132, global: 0.0132/0.1970/0.1051
# epoch [1500/5000]:
# [training set] local: 0.0057/0.0176/0.0117, global: 0.0122/0.1955/0.1039
# [validation set] local: 0.0057/0.0197/0.0127, global: 0.0122/0.1962/0.1042
# epoch [2000/5000]:
# [training set] local: 0.0054/0.0172/0.0113, global: 0.0115/0.1909/0.1012
# [validation set] local: 0.0054/0.0184/0.0119, global: 0.0115/0.1923/0.1019
# epoch [2500/5000]:
# [training set] local: 0.0052/0.0150/0.0101, global: 0.0107/0.1823/0.0965
# [validation set] local: 0.0052/0.0168/0.0110, global: 0.0107/0.1846/0.0976
# epoch [3000/5000]:
# [training set] local: 0.0049/0.0127/0.0088, global: 0.0104/0.1736/0.0920
# [validation set] local: 0.0049/0.0144/0.0097, global: 0.0103/0.1768/0.0936
# epoch [3500/5000]:
# [training set] local: 0.0045/0.0111/0.0078, global: 0.0098/0.1647/0.0873
# [validation set] local: 0.0045/0.0128/0.0087, global: 0.0098/0.1692/0.0895
# epoch [4000/5000]:
# [training set] local: 0.0044/0.0103/0.0073, global: 0.0095/0.1642/0.0869
# [validation set] local: 0.0044/0.0123/0.0083, global: 0.0095/0.1718/0.0906
# epoch [4500/5000]:
# [training set] local: 0.0044/0.0098/0.0071, global: 0.0094/0.1708/0.0901
# [validation set] local: 0.0044/0.0117/0.0080, global: 0.0094/0.1787/0.0940
# early stopping at 4500th iteration due to slow convergence!
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0043/0.0105/0.0074, global: 0.0091/0.1645/0.0868
# [validation set] local: 0.0043/0.0119/0.0081, global: 0.0091/0.1723/0.0907
# epoch [500/5000]:
# [training set] local: 0.0040/0.0093/0.0067, global: 0.0089/0.1620/0.0854
# [validation set] local: 0.0040/0.0109/0.0074, global: 0.0088/0.1699/0.0894
# epoch [1000/5000]:
# [training set] local: 0.0039/0.0089/0.0064, global: 0.0089/0.1627/0.0858
# [validation set] local: 0.0039/0.0107/0.0073, global: 0.0089/0.1706/0.0898
# epoch [1500/5000]:
# [training set] local: 0.0038/0.0085/0.0062, global: 0.0086/0.1579/0.0832
# [validation set] local: 0.0038/0.0104/0.0071, global: 0.0086/0.1656/0.0871
# epoch [2000/5000]:
# [training set] local: 0.0038/0.0082/0.0060, global: 0.0087/0.1600/0.0843
# [validation set] local: 0.0038/0.0097/0.0067, global: 0.0086/0.1678/0.0882
# epoch [2500/5000]:
# [training set] local: 0.0035/0.0080/0.0058, global: 0.0083/0.1557/0.0820
# [validation set] local: 0.0035/0.0094/0.0064, global: 0.0083/0.1634/0.0859
# epoch [3000/5000]:
# [training set] local: 0.0035/0.0077/0.0056, global: 0.0083/0.1547/0.0815
# [validation set] local: 0.0035/0.0092/0.0063, global: 0.0083/0.1624/0.0853
# epoch [3500/5000]:
# [training set] local: 0.0034/0.0076/0.0055, global: 0.0083/0.1507/0.0795
# [validation set] local: 0.0034/0.0087/0.0060, global: 0.0082/0.1583/0.0833
# epoch [4000/5000]:
# [training set] local: 0.0033/0.0074/0.0053, global: 0.0082/0.1495/0.0788
# [validation set] local: 0.0033/0.0087/0.0060, global: 0.0082/0.1571/0.0826
# epoch [4500/5000]:
# [training set] local: 0.0031/0.0070/0.0050, global: 0.0080/0.1405/0.0742
# [validation set] local: 0.0031/0.0080/0.0055, global: 0.0079/0.1479/0.0779
# epoch [5000/5000]:
# [training set] local: 0.0029/0.0068/0.0048, global: 0.0078/0.1415/0.0747
# [validation set] local: 0.0029/0.0079/0.0054, global: 0.0078/0.1473/0.0776
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0029/0.0079/0.0054, global: 0.0076/0.1359/0.0717
# [validation set] local: 0.0029/0.0089/0.0059, global: 0.0075/0.1414/0.0745
# epoch [500/5000]:
# [training set] local: 0.0027/0.0066/0.0047, global: 0.0078/0.1424/0.0751
# [validation set] local: 0.0027/0.0076/0.0051, global: 0.0077/0.1455/0.0766
# epoch [1000/5000]:
# [training set] local: 0.0025/0.0064/0.0044, global: 0.0077/0.1408/0.0742
# [validation set] local: 0.0025/0.0073/0.0049, global: 0.0077/0.1443/0.0760
# early stopping at 1000th iteration due to satisfying reconstruction!
#
# -------------------------------------------------
# *************************************************
# # of filters in each group:  [3, 3, 3, 3]
# *************************************************
# Model @Level 2:
# Perform deepening & widening, train each architectures ...
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0147/0.1445/0.0796, global: 0.0170/0.1932/0.1051
# [validation set] local: 0.0147/0.1396/0.0771, global: 0.0169/0.1910/0.1040
# epoch [500/5000]:
# [training set] local: 0.0063/0.0252/0.0158, global: 0.0065/0.0736/0.0400
# [validation set] local: 0.0064/0.0287/0.0175, global: 0.0065/0.0747/0.0406
# epoch [1000/5000]:
# [training set] local: 0.0065/0.0239/0.0152, global: 0.0065/0.0708/0.0386
# [validation set] local: 0.0065/0.0274/0.0169, global: 0.0065/0.0729/0.0397
# epoch [1500/5000]:
# [training set] local: 0.0064/0.0233/0.0148, global: 0.0065/0.0790/0.0428
# [validation set] local: 0.0064/0.0262/0.0163, global: 0.0065/0.0813/0.0439
# epoch [2000/5000]:
# [training set] local: 0.0063/0.0239/0.0151, global: 0.0065/0.0779/0.0422
# [validation set] local: 0.0063/0.0247/0.0155, global: 0.0065/0.0802/0.0433
# epoch [2500/5000]:
# [training set] local: 0.0065/0.0230/0.0147, global: 0.0065/0.0756/0.0411
# [validation set] local: 0.0065/0.0265/0.0165, global: 0.0065/0.0779/0.0422
# epoch [3000/5000]:
# [training set] local: 0.0063/0.0232/0.0148, global: 0.0064/0.0771/0.0417
# [validation set] local: 0.0063/0.0264/0.0164, global: 0.0064/0.0794/0.0429
# epoch [3500/5000]:
# [training set] local: 0.0063/0.0226/0.0145, global: 0.0064/0.0813/0.0439
# [validation set] local: 0.0063/0.0248/0.0155, global: 0.0064/0.0836/0.0450
# epoch [4000/5000]:
# [training set] local: 0.0061/0.0230/0.0146, global: 0.0063/0.0737/0.0400
# [validation set] local: 0.0062/0.0254/0.0158, global: 0.0063/0.0760/0.0411
# early stopping at 4000th iteration due to slow convergence!
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0062/0.0249/0.0155, global: 0.0063/0.0700/0.0382
# [validation set] local: 0.0062/0.0277/0.0170, global: 0.0063/0.0722/0.0392
# epoch [500/5000]:
# [training set] local: 0.0048/0.0182/0.0115, global: 0.0053/0.0674/0.0364
# [validation set] local: 0.0049/0.0206/0.0127, global: 0.0053/0.0684/0.0369
# epoch [1000/5000]:
# [training set] local: 0.0037/0.0135/0.0086, global: 0.0041/0.0560/0.0301
# [validation set] local: 0.0037/0.0151/0.0094, global: 0.0041/0.0597/0.0319
# epoch [1500/5000]:
# [training set] local: 0.0035/0.0115/0.0075, global: 0.0038/0.0544/0.0291
# [validation set] local: 0.0035/0.0125/0.0080, global: 0.0038/0.0557/0.0298
# epoch [2000/5000]:
# [training set] local: 0.0032/0.0094/0.0063, global: 0.0034/0.0482/0.0258
# [validation set] local: 0.0033/0.0117/0.0075, global: 0.0034/0.0497/0.0266
# epoch [2500/5000]:
# [training set] local: 0.0030/0.0096/0.0063, global: 0.0032/0.0490/0.0261
# [validation set] local: 0.0030/0.0106/0.0068, global: 0.0032/0.0495/0.0263
# epoch [3000/5000]:
# [training set] local: 0.0029/0.0093/0.0061, global: 0.0032/0.0490/0.0261
# [validation set] local: 0.0029/0.0099/0.0064, global: 0.0031/0.0494/0.0263
# epoch [3500/5000]:
# [training set] local: 0.0028/0.0086/0.0057, global: 0.0031/0.0456/0.0244
# [validation set] local: 0.0028/0.0099/0.0064, global: 0.0031/0.0480/0.0255
# epoch [4000/5000]:
# [training set] local: 0.0029/0.0088/0.0058, global: 0.0031/0.0467/0.0249
# [validation set] local: 0.0029/0.0097/0.0063, global: 0.0031/0.0476/0.0253
# epoch [4500/5000]:
# [training set] local: 0.0027/0.0089/0.0058, global: 0.0029/0.0494/0.0262
# [validation set] local: 0.0027/0.0101/0.0064, global: 0.0029/0.0506/0.0268
# epoch [5000/5000]:
# [training set] local: 0.0028/0.0093/0.0061, global: 0.0030/0.0444/0.0237
# [validation set] local: 0.0028/0.0103/0.0065, global: 0.0030/0.0453/0.0242
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0028/0.0084/0.0056, global: 0.0030/0.0466/0.0248
# [validation set] local: 0.0028/0.0098/0.0063, global: 0.0030/0.0474/0.0252
# epoch [500/5000]:
# [training set] local: 0.0026/0.0092/0.0059, global: 0.0029/0.0501/0.0265
# [validation set] local: 0.0026/0.0093/0.0060, global: 0.0029/0.0507/0.0268
# epoch [1000/5000]:
# [training set] local: 0.0026/0.0088/0.0057, global: 0.0029/0.0463/0.0246
# [validation set] local: 0.0026/0.0094/0.0060, global: 0.0029/0.0473/0.0251
# epoch [1500/5000]:
# [training set] local: 0.0026/0.0082/0.0054, global: 0.0029/0.0453/0.0241
# [validation set] local: 0.0026/0.0092/0.0059, global: 0.0029/0.0459/0.0244
# epoch [2000/5000]:
# [training set] local: 0.0025/0.0094/0.0059, global: 0.0028/0.0423/0.0225
# [validation set] local: 0.0025/0.0102/0.0064, global: 0.0028/0.0415/0.0221
# epoch [2500/5000]:
# [training set] local: 0.0025/0.0081/0.0053, global: 0.0028/0.0482/0.0255
# [validation set] local: 0.0025/0.0088/0.0057, global: 0.0028/0.0469/0.0249
# epoch [3000/5000]:
# [training set] local: 0.0024/0.0074/0.0049, global: 0.0027/0.0447/0.0237
# [validation set] local: 0.0024/0.0085/0.0055, global: 0.0027/0.0453/0.0240
# epoch [3500/5000]:
# [training set] local: 0.0024/0.0078/0.0051, global: 0.0027/0.0461/0.0244
# [validation set] local: 0.0024/0.0082/0.0053, global: 0.0027/0.0466/0.0247
# early stopping at 3500th iteration due to slow convergence!
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0025/0.0083/0.0054, global: 0.0028/0.0474/0.0251
# [validation set] local: 0.0025/0.0086/0.0055, global: 0.0028/0.0478/0.0253
# epoch [500/5000]:
# [training set] local: 0.0024/0.0075/0.0050, global: 0.0027/0.0449/0.0238
# [validation set] local: 0.0024/0.0081/0.0052, global: 0.0027/0.0459/0.0243
# epoch [1000/5000]:
# [training set] local: 0.0023/0.0081/0.0052, global: 0.0026/0.0438/0.0232
# [validation set] local: 0.0023/0.0088/0.0056, global: 0.0026/0.0437/0.0232
# epoch [1500/5000]:
# [training set] local: 0.0024/0.0087/0.0055, global: 0.0027/0.0486/0.0256
# [validation set] local: 0.0024/0.0088/0.0056, global: 0.0027/0.0484/0.0256
# epoch [2000/5000]:
# [training set] local: 0.0022/0.0079/0.0051, global: 0.0026/0.0440/0.0233
# [validation set] local: 0.0022/0.0086/0.0054, global: 0.0026/0.0454/0.0240
# epoch [2500/5000]:
# [training set] local: 0.0022/0.0073/0.0047, global: 0.0026/0.0466/0.0246
# [validation set] local: 0.0022/0.0079/0.0051, global: 0.0025/0.0482/0.0254
# epoch [3000/5000]:
# [training set] local: 0.0021/0.0070/0.0046, global: 0.0025/0.0430/0.0227
# [validation set] local: 0.0021/0.0076/0.0049, global: 0.0025/0.0444/0.0235
# epoch [3500/5000]:
# [training set] local: 0.0021/0.0068/0.0045, global: 0.0025/0.0459/0.0242
# [validation set] local: 0.0021/0.0073/0.0047, global: 0.0025/0.0469/0.0247
# early stopping at 3500th iteration due to slow convergence!
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0021/0.0067/0.0044, global: 0.0025/0.0450/0.0237
# [validation set] local: 0.0021/0.0074/0.0048, global: 0.0025/0.0463/0.0244
# epoch [500/5000]:
# [training set] local: 0.0022/0.0073/0.0047, global: 0.0026/0.0450/0.0238
# [validation set] local: 0.0022/0.0072/0.0047, global: 0.0025/0.0457/0.0241
# epoch [1000/5000]:
# [training set] local: 0.0020/0.0074/0.0047, global: 0.0024/0.0428/0.0226
# [validation set] local: 0.0020/0.0080/0.0050, global: 0.0024/0.0418/0.0221
# epoch [1500/5000]:
# [training set] local: 0.0020/0.0069/0.0044, global: 0.0024/0.0458/0.0241
# [validation set] local: 0.0020/0.0073/0.0046, global: 0.0024/0.0453/0.0239
# epoch [2000/5000]:
# [training set] local: 0.0020/0.0063/0.0042, global: 0.0024/0.0445/0.0235
# [validation set] local: 0.0020/0.0069/0.0044, global: 0.0024/0.0439/0.0232
# epoch [2500/5000]:
# [training set] local: 0.0019/0.0067/0.0043, global: 0.0024/0.0422/0.0223
# [validation set] local: 0.0019/0.0073/0.0046, global: 0.0024/0.0404/0.0214
# epoch [3000/5000]:
# [training set] local: 0.0019/0.0066/0.0042, global: 0.0024/0.0462/0.0243
# [validation set] local: 0.0019/0.0073/0.0046, global: 0.0023/0.0438/0.0231
# epoch [3500/5000]:
# [training set] local: 0.0019/0.0064/0.0042, global: 0.0024/0.0452/0.0238
# [validation set] local: 0.0019/0.0067/0.0043, global: 0.0024/0.0440/0.0232
# epoch [4000/5000]:
# [training set] local: 0.0019/0.0060/0.0039, global: 0.0023/0.0420/0.0222
# [validation set] local: 0.0019/0.0067/0.0043, global: 0.0023/0.0413/0.0218
# early stopping at 4000th iteration due to slow convergence!
#
# -------------------------------------------------
# *************************************************
# # of filters in each group:  [5, 5, 5, 5]
# *************************************************
# Model @Level 3:
# Perform deepening & widening, train each architectures ...
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0083/0.0628/0.0356, global: 0.0083/0.0628/0.0356
# [validation set] local: 0.0082/0.0632/0.0357, global: 0.0082/0.0632/0.0357
# epoch [500/5000]:
# [training set] local: 0.0026/0.0143/0.0085, global: 0.0026/0.0143/0.0085
# [validation set] local: 0.0026/0.0173/0.0100, global: 0.0026/0.0173/0.0100
# epoch [1000/5000]:
# [training set] local: 0.0026/0.0140/0.0083, global: 0.0026/0.0140/0.0083
# [validation set] local: 0.0026/0.0162/0.0094, global: 0.0026/0.0162/0.0094
# epoch [1500/5000]:
# [training set] local: 0.0027/0.0148/0.0088, global: 0.0027/0.0148/0.0088
# [validation set] local: 0.0027/0.0152/0.0089, global: 0.0027/0.0152/0.0089
# epoch [2000/5000]:
# [training set] local: 0.0026/0.0135/0.0080, global: 0.0026/0.0135/0.0080
# [validation set] local: 0.0025/0.0160/0.0093, global: 0.0025/0.0160/0.0093
# epoch [2500/5000]:
# [training set] local: 0.0026/0.0137/0.0081, global: 0.0026/0.0137/0.0081
# [validation set] local: 0.0026/0.0163/0.0094, global: 0.0026/0.0163/0.0094
# epoch [3000/5000]:
# [training set] local: 0.0027/0.0148/0.0087, global: 0.0027/0.0148/0.0087
# [validation set] local: 0.0027/0.0164/0.0096, global: 0.0027/0.0164/0.0096
# epoch [3500/5000]:
# [training set] local: 0.0026/0.0135/0.0080, global: 0.0026/0.0135/0.0080
# [validation set] local: 0.0026/0.0145/0.0085, global: 0.0026/0.0145/0.0085
# epoch [4000/5000]:
# [training set] local: 0.0025/0.0137/0.0081, global: 0.0025/0.0137/0.0081
# [validation set] local: 0.0025/0.0161/0.0093, global: 0.0025/0.0161/0.0093
# epoch [4500/5000]:
# [training set] local: 0.0025/0.0130/0.0078, global: 0.0025/0.0130/0.0078
# [validation set] local: 0.0025/0.0143/0.0084, global: 0.0025/0.0143/0.0084
# epoch [5000/5000]:
# [training set] local: 0.0025/0.0127/0.0076, global: 0.0025/0.0127/0.0076
# [validation set] local: 0.0025/0.0152/0.0089, global: 0.0025/0.0152/0.0089
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0025/0.0140/0.0082, global: 0.0025/0.0140/0.0082
# [validation set] local: 0.0025/0.0165/0.0095, global: 0.0025/0.0165/0.0095
# epoch [500/5000]:
# [training set] local: 0.0023/0.0098/0.0061, global: 0.0023/0.0098/0.0061
# [validation set] local: 0.0023/0.0106/0.0064, global: 0.0023/0.0106/0.0064
# epoch [1000/5000]:
# [training set] local: 0.0021/0.0088/0.0054, global: 0.0021/0.0088/0.0054
# [validation set] local: 0.0021/0.0093/0.0057, global: 0.0021/0.0093/0.0057
# epoch [1500/5000]:
# [training set] local: 0.0020/0.0080/0.0050, global: 0.0020/0.0080/0.0050
# [validation set] local: 0.0020/0.0091/0.0055, global: 0.0020/0.0091/0.0055
# epoch [2000/5000]:
# [training set] local: 0.0019/0.0075/0.0047, global: 0.0019/0.0075/0.0047
# [validation set] local: 0.0019/0.0092/0.0056, global: 0.0019/0.0092/0.0056
# epoch [2500/5000]:
# [training set] local: 0.0019/0.0073/0.0046, global: 0.0019/0.0073/0.0046
# [validation set] local: 0.0019/0.0086/0.0052, global: 0.0019/0.0086/0.0052
# epoch [3000/5000]:
# [training set] local: 0.0018/0.0074/0.0046, global: 0.0018/0.0074/0.0046
# [validation set] local: 0.0018/0.0086/0.0052, global: 0.0018/0.0086/0.0052
# epoch [3500/5000]:
# [training set] local: 0.0018/0.0069/0.0043, global: 0.0018/0.0069/0.0043
# [validation set] local: 0.0018/0.0088/0.0053, global: 0.0018/0.0088/0.0053
# epoch [4000/5000]:
# [training set] local: 0.0017/0.0069/0.0043, global: 0.0017/0.0069/0.0043
# [validation set] local: 0.0017/0.0083/0.0050, global: 0.0017/0.0083/0.0050
# epoch [4500/5000]:
# [training set] local: 0.0017/0.0070/0.0044, global: 0.0017/0.0070/0.0044
# [validation set] local: 0.0017/0.0078/0.0048, global: 0.0017/0.0078/0.0048
# epoch [5000/5000]:
# [training set] local: 0.0017/0.0072/0.0044, global: 0.0017/0.0072/0.0044
# [validation set] local: 0.0017/0.0089/0.0053, global: 0.0017/0.0089/0.0053
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0018/0.0074/0.0046, global: 0.0018/0.0074/0.0046
# [validation set] local: 0.0017/0.0093/0.0055, global: 0.0017/0.0093/0.0055
# epoch [500/5000]:
# [training set] local: 0.0018/0.0066/0.0042, global: 0.0018/0.0066/0.0042
# [validation set] local: 0.0018/0.0085/0.0051, global: 0.0018/0.0085/0.0051
# epoch [1000/5000]:
# [training set] local: 0.0017/0.0070/0.0044, global: 0.0017/0.0070/0.0044
# [validation set] local: 0.0017/0.0083/0.0050, global: 0.0017/0.0083/0.0050
# epoch [1500/5000]:
# [training set] local: 0.0016/0.0067/0.0041, global: 0.0016/0.0067/0.0041
# [validation set] local: 0.0016/0.0080/0.0048, global: 0.0016/0.0080/0.0048
# epoch [2000/5000]:
# [training set] local: 0.0016/0.0067/0.0042, global: 0.0016/0.0067/0.0042
# [validation set] local: 0.0016/0.0074/0.0045, global: 0.0016/0.0074/0.0045
# epoch [2500/5000]:
# [training set] local: 0.0016/0.0064/0.0040, global: 0.0016/0.0064/0.0040
# [validation set] local: 0.0016/0.0070/0.0043, global: 0.0016/0.0070/0.0043
# epoch [3000/5000]:
# [training set] local: 0.0015/0.0074/0.0045, global: 0.0015/0.0074/0.0045
# [validation set] local: 0.0015/0.0081/0.0048, global: 0.0015/0.0081/0.0048
# epoch [3500/5000]:
# [training set] local: 0.0017/0.0069/0.0043, global: 0.0017/0.0069/0.0043
# [validation set] local: 0.0017/0.0068/0.0043, global: 0.0017/0.0068/0.0043
# early stopping at 3500th iteration due to slow convergence!
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0015/0.0074/0.0045, global: 0.0015/0.0074/0.0045
# [validation set] local: 0.0015/0.0084/0.0050, global: 0.0015/0.0084/0.0050
# epoch [500/5000]:
# [training set] local: 0.0015/0.0071/0.0043, global: 0.0015/0.0071/0.0043
# [validation set] local: 0.0015/0.0077/0.0046, global: 0.0015/0.0077/0.0046
# epoch [1000/5000]:
# [training set] local: 0.0015/0.0062/0.0038, global: 0.0015/0.0062/0.0038
# [validation set] local: 0.0015/0.0067/0.0041, global: 0.0015/0.0067/0.0041
# epoch [1500/5000]:
# [training set] local: 0.0015/0.0070/0.0043, global: 0.0015/0.0070/0.0043
# [validation set] local: 0.0015/0.0072/0.0043, global: 0.0015/0.0072/0.0043
# epoch [2000/5000]:
# [training set] local: 0.0015/0.0062/0.0038, global: 0.0015/0.0062/0.0038
# [validation set] local: 0.0015/0.0069/0.0042, global: 0.0015/0.0069/0.0042
# epoch [2500/5000]:
# [training set] local: 0.0014/0.0066/0.0040, global: 0.0014/0.0066/0.0040
# [validation set] local: 0.0014/0.0075/0.0045, global: 0.0014/0.0075/0.0045
# epoch [3000/5000]:
# [training set] local: 0.0015/0.0057/0.0036, global: 0.0015/0.0057/0.0036
# [validation set] local: 0.0014/0.0060/0.0037, global: 0.0014/0.0060/0.0037
# epoch [3500/5000]:
# [training set] local: 0.0015/0.0058/0.0036, global: 0.0015/0.0058/0.0036
# [validation set] local: 0.0015/0.0066/0.0040, global: 0.0015/0.0066/0.0040
# epoch [4000/5000]:
# [training set] local: 0.0015/0.0065/0.0040, global: 0.0015/0.0065/0.0040
# [validation set] local: 0.0015/0.0067/0.0041, global: 0.0015/0.0067/0.0041
# epoch [4500/5000]:
# [training set] local: 0.0014/0.0064/0.0039, global: 0.0014/0.0064/0.0039
# [validation set] local: 0.0014/0.0069/0.0042, global: 0.0014/0.0069/0.0042
# early stopping at 4500th iteration due to slow convergence!
#
# -------------------------------------------------
# losses printing format: local: mse/max/overall, global: mse/max/overall
# epoch [1/5000]
# [training set] local: 0.0015/0.0070/0.0042, global: 0.0015/0.0070/0.0042
# [validation set] local: 0.0015/0.0074/0.0044, global: 0.0015/0.0074/0.0044
# epoch [500/5000]:
# [training set] local: 0.0014/0.0062/0.0038, global: 0.0014/0.0062/0.0038
# [validation set] local: 0.0013/0.0064/0.0039, global: 0.0013/0.0064/0.0039
# epoch [1000/5000]:
# [training set] local: 0.0014/0.0060/0.0037, global: 0.0014/0.0060/0.0037
# [validation set] local: 0.0014/0.0063/0.0039, global: 0.0014/0.0063/0.0039
# epoch [1500/5000]:
# [training set] local: 0.0014/0.0067/0.0040, global: 0.0014/0.0067/0.0040
# [validation set] local: 0.0014/0.0066/0.0040, global: 0.0014/0.0066/0.0040
# epoch [2000/5000]:
# [training set] local: 0.0014/0.0061/0.0038, global: 0.0014/0.0061/0.0038
# [validation set] local: 0.0014/0.0068/0.0041, global: 0.0014/0.0068/0.0041
# epoch [2500/5000]:
# [training set] local: 0.0014/0.0068/0.0041, global: 0.0014/0.0068/0.0041
# [validation set] local: 0.0014/0.0076/0.0045, global: 0.0014/0.0076/0.0045
# epoch [3000/5000]:
# [training set] local: 0.0014/0.0063/0.0039, global: 0.0014/0.0063/0.0039
# [validation set] local: 0.0014/0.0067/0.0041, global: 0.0014/0.0067/0.0041
# epoch [3500/5000]:
# [training set] local: 0.0014/0.0064/0.0039, global: 0.0014/0.0064/0.0039
# [validation set] local: 0.0014/0.0064/0.0039, global: 0.0014/0.0064/0.0039
# epoch [4000/5000]:
# [training set] local: 0.0014/0.0069/0.0041, global: 0.0014/0.0069/0.0041
# [validation set] local: 0.0014/0.0072/0.0043, global: 0.0014/0.0072/0.0043
# early stopping at 4000th iteration due to slow convergence!
#
# -------------------------------------------------
# *************************************************

# %% [markdown]
# ### Results

# %%
# trained models at different levels
models = {}
print('model names: model_L{level}_{index}')
for file_name in sorted(os.listdir(model_path)):
    model_name, _ = file_name.split('.')
    print(model_name)
    models[model_name] = torch.load(os.path.join(model_path, file_name))
# Out:
# model names: model_L{level}_{index}
# model_L0_0
# model_L1_0
# model_L1_1
# model_L1_2
# model_L1_3
# model_L2_0
# model_L2_1
# model_L2_2
# model_L2_3
# model_L2_4
# model_L3_0
# model_L3_1
# model_L3_2
# model_L3_3
# model_L3_4

# %%
# choose the finest model
model = models['model_L3_4']

# resolved maps at different levels (that suggest poorly reconstructed regions)
for i in range(4):
    print(model.resolved_maps[str(i)].keys())
    
for i in range(4):
    level_maps = model.resolved_maps[str(i)]
    for key in level_maps.keys():
        if key == '0':
            intensities = (1 - level_maps[key])
        else:
            intensities += (1 - level_maps[key])
    file_name = 'L{}.png'.format(i)
    fig, ax = plt.subplots(1, 1, figsize=(4, 16))
    ax.imshow(intensities.cpu().detach().numpy(), cmap='hot')
    ax.set_xticks([])
    ax.set_yticks([])
    fig.savefig(os.path.join(result_path, file_name))
# Out:
# dict_keys(['0'])
# dict_keys(['0', '1', '2', '3'])
# dict_keys(['0', '1', '2', '3', '4'])
# dict_keys(['0', '1', '2', '3', '4'])

# %%
inds = np.array(sorted(dataset.test_inds))
dataset.test_inds = inds
n_snapshots = len(inds)
n_samples = 3
n_step = n_snapshots // 3

fig, axes = plt.subplots(1, n_samples, figsize=(n_samples*16, 4))
plt.subplots_adjust(wspace=0.01)
for i in range(n_samples):
    axes[i].imshow(dataset.data[inds[i*n_step], :, :, :].squeeze().T.cpu().detach().numpy(), cmap='viridis')
    axes[i].set_xticks([])
    axes[i].set_yticks([])
fig.savefig(os.path.join(result_path, 'test_samples.png'), bbox_inches='tight')


model = models['model_L0_0']
fig, axes = plt.subplots(1, n_samples, figsize=(n_samples*16, 4))
plt.subplots_adjust(wspace=0.01)
for i in range(n_samples):
    _, _, data = dataset.obtain_data_at_current_level(level=0)
    output, _, _, _ = model(data[[i*n_step], :, :, :], model.cur_level)
    axes[i].imshow(output.squeeze().cpu().T.detach().numpy(), cmap='viridis')
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    
fig.savefig(os.path.join(result_path, 'test_L0_reconstructions.png'), bbox_inches='tight')


model = models['model_L1_3']
fig, axes = plt.subplots(1, n_samples, figsize=(n_samples*16, 4))
plt.subplots_adjust(wspace=0.01)
for i in range(n_samples):
    _, _, data = dataset.obtain_data_at_current_level(level=1)
    output, _, _, _ = model(data[[i*n_step], :, :, :], model.cur_level)
    axes[i].imshow(output.squeeze().cpu().T.detach().numpy(), cmap='viridis')
    axes[i].set_xticks([])
    axes[i].set_yticks([])
fig.savefig(os.path.join(result_path, 'test_L1_reconstructions.png'), bbox_inches='tight')


model = models['model_L2_4']
fig, axes = plt.subplots(1, n_samples, figsize=(n_samples*16, 4))
plt.subplots_adjust(wspace=0.01)
for i in range(n_samples):
    _, _, data = dataset.obtain_data_at_current_level(level=2)
    output, _, _, _ = model(data[[i*n_step], :, :, :], model.cur_level)
    axes[i].imshow(output.squeeze().cpu().T.detach().numpy(), cmap='viridis')
    axes[i].set_xticks([])
    axes[i].set_yticks([])
fig.savefig(os.path.join(result_path, 'test_L2_reconstructions.png'), bbox_inches='tight')

model = models['model_L3_4']
fig, axes = plt.subplots(1, n_samples, figsize=(n_samples*16, 4))
plt.subplots_adjust(wspace=0.01)
for i in range(n_samples):
    _, _, data = dataset.obtain_data_at_current_level(level=3)
    output, _, _, _ = model(data[[i*n_step], :, :, :], model.cur_level)
    axes[i].imshow(output.squeeze().cpu().T.detach().numpy(), cmap='viridis')
    axes[i].set_xticks([])
    axes[i].set_yticks([])
fig.savefig(os.path.join(result_path, 'test_L3_reconstructions.png'), bbox_inches='tight')

# %%
records = {}
for file_name in sorted(os.listdir(result_path)):
    if file_name.endswith('.dat'):
        key, _ = file_name.split('.')
        with open(os.path.join(result_path, file_name), 'rb') as f: 
            records[key]= pickle.load(f)

# %%
n_colors = 4
colors = [(51/255, 51/255, 255/255)]+ \
         [(204/255, 153/255, 255/255), 
          (178/255, 102/255, 255/255),
          (153/255, 51/255, 255/255),
          (127/255, 0/255, 255/255),
          (102/255, 0/255, 204/255),
          (76/255, 0/255, 153/255)]

fig1, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(100, 16))

# plot
s = 0
for i in range(4):
    level_errs = records['val_errs'][i]
    n_widens = len(level_errs)
    ax1.axvline(x=s, color='k', linestyle='--', linewidth=20)
    for j in range(n_widens):
        op_err = level_errs[j]
        ax1.plot(range(s, s + len(op_err)), np.log(op_err), color=colors[j], linewidth=20)
        s += len(op_err)
        
ax1.axvline(x=s-1, color='k', linestyle='--', linewidth=20)

ax1.xaxis.set_tick_params(labelsize=100)
ax1.yaxis.set_tick_params(labelsize=100)

fig1.savefig(os.path.join(result_path, 'err_iter_plot.png'))
